# %%
# 패키지 설치
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
user_spec = pd.read_csv('/content/gdrive/MyDrive/dataset/user_spec.csv')
loan_data = pd.read_csv('/content/gdrive/MyDrive/dataset/loan_result.csv')

# %%
user_spec.isnull().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12961
# gender                                   12961
# insert_time                                  0
# credit_score                            105115
# yearly_income                               90
# income_type                                 85
# company_enter_month                     171760
# employment_type                             85
# houseown_type                               85
# desired_amount                              85
# purpose                                     85
# personal_rehabilitation_yn              587461
# personal_rehabilitation_complete_yn    1203354
# existing_loan_cnt                       198556
# existing_loan_amt                       313774
# dtype: int64

# %% [markdown]
# # 1. 공통 된 결측값을 가진 85개 데이터 삭제

# %%
user_spec = user_spec.dropna(subset = ['income_type'])
user_spec.isnull().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12959
# gender                                   12959
# insert_time                                  0
# credit_score                            105112
# yearly_income                                5
# income_type                                  0
# company_enter_month                     171675
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn              587376
# personal_rehabilitation_complete_yn    1203269
# existing_loan_cnt                       198540
# existing_loan_amt                       313752
# dtype: int64

# %%
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS           20151101.0
# 1               870.0     30000000.0  PRIVATEBUSINESS           20070201.0
# 2               710.0     30000000.0       FREELANCER           20210901.0
# 3               820.0     62000000.0     EARNEDINCOME           20170101.0
# 4               630.0     36000000.0     EARNEDINCOME           20210901.0
# ...               ...            ...              ...                  ...
# 1394211         590.0     25000000.0       FREELANCER             202106.0
# 1394212         980.0     20000000.0      OTHERINCOME                  NaN
# 1394213         750.0     75000000.0     EARNEDINCOME             200908.0
# 1394214         640.0     50000000.0     EARNEDINCOME             201705.0
# 1394215           NaN     35000000.0       FREELANCER             201103.0
#
#         employment_type houseown_type  desired_amount purpose  \
# 0                    기타            자가       1000000.0      기타
# 1                   정규직        기타가족소유      30000000.0    대환대출
# 2                    기타        기타가족소유      10000000.0     생활비
# 3                   정규직            자가       2000000.0     생활비
# 4                   정규직        기타가족소유       5000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394211              기타        기타가족소유       5000000.0    사업자금
# 1394212              기타            자가      50000000.0     생활비
# 1394213             정규직            자가     100000000.0    대환대출
# 1394214             정규직            자가      10000000.0    대환대출
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                               0.0                                  NaN
# 1                               0.0                                  NaN
# 2                               0.0                                  NaN
# 3                               0.0                                  NaN
# 4                               0.0                                  0.0
# ...                             ...                                  ...
# 1394211                         NaN                                  NaN
# 1394212                         NaN                                  NaN
# 1394213                         NaN                                  NaN
# 1394214                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 0                      4.0        162000000.0
# 1                      1.0         27000000.0
# 2                      5.0         15000000.0
# 3                      7.0        344000000.0
# 4                      1.0         16000000.0
# ...                    ...                ...
# 1394211                NaN                NaN
# 1394212                1.0                NaN
# 1394213                8.0        200000000.0
# 1394214               10.0        117000000.0
# 1394215                NaN                NaN
#
# [1394131 rows x 17 columns]

# %% [markdown]
# # 2. Birth_year을 나이로

# %%
plt.figure(figsize=(30,8))
sns.distplot(user_spec['birth_year'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
user_spec['age'] = 2023 - user_spec['birth_year']

# %%
plt.figure(figsize=(30,8))
sns.distplot(user_spec['age'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(user_spec["age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
user_spec.loc[user_spec['age'] < 20, 'reage'] = 10
user_spec.loc[(user_spec['age'] >= 20) & (user_spec['age'] <30), 'reage'] = 20
user_spec.loc[(user_spec['age'] >= 30) & (user_spec['age'] <40), 'reage'] = 30
user_spec.loc[(user_spec['age'] >= 40) & (user_spec['age'] <50), 'reage'] = 40
user_spec.loc[(user_spec['age'] >= 50) & (user_spec['age'] <60), 'reage'] = 50
user_spec.loc[(user_spec['age'] >= 60) & (user_spec['age'] <70), 'reage'] = 60
user_spec.loc[user_spec['age'] >= 70, 'reage'] = 70

# %%
user_spec.head(5)
# Out:
#    application_id  user_id  birth_year  gender          insert_time  \
# 0         1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1          954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2          137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3         1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4          967833    33400      2000.0     1.0  2022-06-07 08:55:07
#
#    credit_score  yearly_income      income_type  company_enter_month  \
# 0         660.0    108000000.0  PRIVATEBUSINESS           20151101.0
# 1         870.0     30000000.0  PRIVATEBUSINESS           20070201.0
# 2         710.0     30000000.0       FREELANCER           20210901.0
# 3         820.0     62000000.0     EARNEDINCOME           20170101.0
# 4         630.0     36000000.0     EARNEDINCOME           20210901.0
#
#   employment_type houseown_type  desired_amount purpose  \
# 0              기타            자가       1000000.0      기타
# 1             정규직        기타가족소유      30000000.0    대환대출
# 2              기타        기타가족소유      10000000.0     생활비
# 3             정규직            자가       2000000.0     생활비
# 4             정규직        기타가족소유       5000000.0     생활비
#
#    personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                         0.0                                  NaN
# 1                         0.0                                  NaN
# 2                         0.0                                  NaN
# 3                         0.0                                  NaN
# 4                         0.0                                  0.0
#
#    existing_loan_cnt  existing_loan_amt   age  reage
# 0                4.0        162000000.0  38.0   30.0
# 1                1.0         27000000.0  55.0   50.0
# 2                5.0         15000000.0  26.0   20.0
# 3                7.0        344000000.0  34.0   30.0
# 4                1.0         16000000.0  23.0   20.0

# %% [markdown]
# # 3. 대출 목적 겹치는 것 합치기

# %%
user_spec['purpose'].unique()
# Out:
# array(['기타', '대환대출', '생활비', '사업자금', '주택구입', '전월세보증금', '투자', 'LIVING',
#        'SWITCHLOAN', 'ETC', 'INVEST', '자동차구입', 'BUSINESS', 'BUYCAR',
#        'HOUSEDEPOSIT', 'BUYHOUSE'], dtype=object)

# %% [markdown]
# * 신용대출, 자동차대출, 담보대출, 전세대출
#
# https://steemit.com/kr/@sumisum/6brzfz

# %%
user_spec['purpose'] = user_spec['purpose'].replace("기타", 'ETC').replace("대환대출", 'SWITCHLOAN').replace("생활비", 'LIVING').replace("사업자금", "BUSINESS").replace("주택구입", 'BUYHOUSE').replace("전월세보증금", 'HOUSEDEPOSIT').replace("투자", 'INVEST').replace("자동차구입", 'BUYCAR')

# %%
user_spec['purpose'].unique()
# Out:
# array(['ETC', 'SWITCHLOAN', 'LIVING', 'BUSINESS', 'BUYHOUSE',
#        'HOUSEDEPOSIT', 'INVEST', 'BUYCAR'], dtype=object)

# %%
user_spec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1394131 entries, 0 to 1394215
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   application_id                       1394131 non-null  int64
#  1   user_id                              1394131 non-null  int64
#  2   birth_year                           1381172 non-null  float64
#  3   gender                               1381172 non-null  float64
#  4   insert_time                          1394131 non-null  object
#  5   credit_score                         1289019 non-null  float64
#  6   yearly_income                        1394126 non-null  float64
#  7   income_type                          1394131 non-null  object
#  8   company_enter_month                  1222456 non-null  float64
#  9   employment_type                      1394131 non-null  object
#  10  houseown_type                        1394131 non-null  object
#  11  desired_amount                       1394131 non-null  float64
#  12  purpose                              1394131 non-null  object
#  13  personal_rehabilitation_yn           806755 non-null   float64
#  14  personal_rehabilitation_complete_yn  190862 non-null   float64
#  15  existing_loan_cnt                    1195591 non-null  float64
#  16  existing_loan_amt                    1080379 non-null  float64
#  17  age                                  1381172 non-null  float64
#  18  reage                                1381172 non-null  float64
# dtypes: float64(12), int64(2), object(5)
# memory usage: 212.7+ MB

# %%
sns.boxplot(y= user_spec["age"], x= user_spec["purpose"])

# %%
user_spec.groupby(['purpose']).mean()
# Out:
#               application_id        user_id   birth_year    gender  \
# purpose
# BUSINESS        1.083056e+06  437578.086154  1980.777790  0.697858
# BUYCAR          1.076957e+06  438989.706999  1986.214694  0.812178
# BUYHOUSE        1.083973e+06  436362.846158  1983.697397  0.681699
# ETC             1.079840e+06  438622.859333  1982.462834  0.671482
# HOUSEDEPOSIT    1.087935e+06  439299.895064  1985.916276  0.621204
# INVEST          1.092035e+06  438081.930225  1985.521632  0.862904
# LIVING          1.084111e+06  439967.580608  1983.181228  0.673505
# SWITCHLOAN      1.083899e+06  439263.970746  1983.720593  0.676328
#
#               credit_score  yearly_income  company_enter_month  \
# purpose
# BUSINESS        694.270873   7.164412e+07         5.072147e+06
# BUYCAR          684.433024   5.049731e+07         1.306264e+06
# BUYHOUSE        819.493152   5.450197e+07         4.918962e+06
# ETC             673.352993   4.451424e+07         5.018580e+06
# HOUSEDEPOSIT    716.028147   4.316833e+07         5.073002e+06
# INVEST          769.919451   5.501032e+07         4.982424e+06
# LIVING          625.478551   4.096931e+07         5.142721e+06
# SWITCHLOAN      640.013624   4.350789e+07         5.145603e+06
#
#               desired_amount  personal_rehabilitation_yn  \
# purpose
# BUSINESS        4.494958e+07                    0.015288
# BUYCAR          2.970332e+07                    0.031042
# BUYHOUSE        1.718995e+08                    0.010926
# ETC             4.240260e+07                    0.022669
# HOUSEDEPOSIT    7.786010e+07                    0.027570
# INVEST          6.792337e+07                    0.006240
# LIVING          2.037487e+07                    0.018038
# SWITCHLOAN      3.950921e+07                    0.009272
#
#               personal_rehabilitation_complete_yn  existing_loan_cnt  \
# purpose
# BUSINESS                                 0.011308           3.504064
# BUYCAR                                   0.021127           3.039635
# BUYHOUSE                                 0.007347           2.538954
# ETC                                      0.009895           4.010702
# HOUSEDEPOSIT                             0.010152           2.772844
# INVEST                                   0.008980           3.651293
# LIVING                                   0.007151           5.001972
# SWITCHLOAN                               0.005657           4.636365
#
#               existing_loan_amt        age      reage
# purpose
# BUSINESS           8.042556e+07  42.222210  37.826143
# BUYCAR             6.421831e+07  36.785306  32.312750
# BUYHOUSE           8.886561e+07  39.302603  34.962895
# ETC                6.911641e+07  40.537166  36.138659
# HOUSEDEPOSIT       5.413286e+07  37.083724  32.599745
# INVEST             9.522019e+07  37.478368  33.018973
# LIVING             6.913450e+07  39.818772  35.376081
# SWITCHLOAN         7.277597e+07  39.279407  34.863491

# %%
user_spec.groupby(['reage']).mean()
# Out:
#        application_id        user_id   birth_year    gender  credit_score  \
# reage
# 10.0     1.064194e+06  455693.868421  2005.017544  0.763158    727.894737
# 20.0     1.084303e+06  440691.349461  1996.726845  0.710269    626.343699
# 30.0     1.084433e+06  440882.277204  1988.671923  0.701614    641.346381
# 40.0     1.081947e+06  436590.725867  1979.070624  0.650786    641.188582
# 50.0     1.086161e+06  441002.207551  1969.441814  0.653708    638.356915
# 60.0     1.086536e+06  437587.806977  1959.664978  0.603164    641.153846
# 70.0     1.093017e+06  451108.777550  1948.812852  0.509363    669.453841
#
#        yearly_income  company_enter_month  desired_amount  \
# reage
# 10.0    2.371053e+07         5.469021e+06    2.783596e+08
# 20.0    2.933934e+07         5.344644e+06    1.977717e+07
# 30.0    4.047910e+07         5.117083e+06    3.138149e+07
# 40.0    4.914588e+07         5.033486e+06    3.288367e+07
# 50.0    5.745686e+07         4.963377e+06    3.586131e+07
# 60.0    4.716989e+07         5.068176e+06    3.395843e+07
# 70.0    3.590279e+07         5.805380e+06    2.202415e+07
#
#        personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# reage
# 10.0                     0.101124                             0.210526
# 20.0                     0.011120                             0.002367
# 30.0                     0.014037                             0.006113
# 40.0                     0.018161                             0.014178
# 50.0                     0.020097                             0.026471
# 60.0                     0.019472                             0.030141
# 70.0                     0.010503                             0.009317
#
#        existing_loan_cnt  existing_loan_amt        age
# reage
# 10.0            1.000000                NaN  17.982456
# 20.0            3.824053       3.401478e+07  26.273155
# 30.0            4.710535       6.765369e+07  34.328077
# 40.0            5.144666       8.840543e+07  43.929376
# 50.0            5.081826       8.694078e+07  53.558186
# 60.0            4.901452       6.487075e+07  63.335022
# 70.0            4.899381       5.294928e+07  74.187148

# %% [markdown]
# * 연간 소득은 나이에 따라 차이가 제일 크기 때문에 나이는 연관 소득과 관련해서 채우면 좋을 것 같음

# %% [markdown]
# # 3. 연관 소득 결측값

# %%
user_spec_1 = user_spec.fillna({'yearly_income': 'NaN'})
user_spec_1[user_spec_1['yearly_income'] == 'NaN']
# Out:
#         application_id  user_id  birth_year  gender          insert_time  \
# 165422         1026915   861363      1995.0     1.0  2022-06-30 21:11:51
# 233316         2045613   702899      1995.0     1.0  2022-06-30 18:37:04
# 597591          391560   329226      1996.0     0.0  2022-06-30 19:27:28
# 597613          341149   670502      1981.0     1.0  2022-06-30 21:32:18
# 971960         1330905   771592      2003.0     1.0  2022-06-30 18:57:05
#
#         credit_score yearly_income  income_type  company_enter_month  \
# 165422           NaN           NaN  OTHERINCOME                  NaN
# 233316         520.0           NaN   FREELANCER           20220630.0
# 597591         590.0           NaN  OTHERINCOME                  NaN
# 597613         930.0           NaN  OTHERINCOME                  NaN
# 971960         750.0           NaN  OTHERINCOME                  NaN
#
#        employment_type houseown_type  desired_amount       purpose  \
# 165422              기타           전월세       5000000.0        LIVING
# 233316              기타           전월세       5000000.0  HOUSEDEPOSIT
# 597591              기타           전월세      20000000.0        LIVING
# 597613              기타        기타가족소유       6000000.0      BUSINESS
# 971960              기타            자가       3000000.0        LIVING
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 165422                         0.0                                  0.0
# 233316                         0.0                                  0.0
# 597591                         0.0                                  0.0
# 597613                         0.0                                  0.0
# 971960                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt   age  reage
# 165422                NaN                NaN  28.0   20.0
# 233316                1.0          1000000.0  28.0   20.0
# 597591                9.0         27000000.0  27.0   20.0
# 597613                1.0          3000000.0  42.0   40.0
# 971960                1.0          3000000.0  20.0   20.0

# %% [markdown]
# * 연간 소득이 결측값인 것 중 OTHERINCOME	은 무직이라 판단하여 : 0
# * 프리렌서는 같은 나이 대 (20대) 중 프리렌서의 연간 소득의 평균 대입 : 27482640

# %%
user_spec['income_type'].unique()
# Out:
# array(['PRIVATEBUSINESS', 'FREELANCER', 'EARNEDINCOME', 'OTHERINCOME',
#        'EARNEDINCOME2', 'PRACTITIONER'], dtype=object)

# %% [markdown]
# * EARNEDINCOME2 는 전문직 인듯

# %%
grouped = user_spec.groupby(['reage', 'income_type'])['yearly_income'].mean()
grouped
# Out:
# reage  income_type
# 10.0   EARNEDINCOME       3.240000e+08
#        EARNEDINCOME2      4.500000e+07
#        FREELANCER         2.000000e+07
#        OTHERINCOME        4.463158e+06
# 20.0   EARNEDINCOME       3.147551e+07
#        EARNEDINCOME2      2.519769e+07
#        FREELANCER         2.748264e+07
#        OTHERINCOME        1.719249e+07
#        PRACTITIONER       3.120135e+07
#        PRIVATEBUSINESS    5.659056e+07
# 30.0   EARNEDINCOME       4.046537e+07
#        EARNEDINCOME2      3.353194e+07
#        FREELANCER         3.944012e+07
#        OTHERINCOME        2.422685e+07
#        PRACTITIONER       5.007317e+07
#        PRIVATEBUSINESS    6.450014e+07
# 40.0   EARNEDINCOME       4.907662e+07
#        EARNEDINCOME2      3.888079e+07
#        FREELANCER         4.040184e+07
#        OTHERINCOME        3.116387e+07
#        PRACTITIONER       6.533972e+07
#        PRIVATEBUSINESS    7.374286e+07
# 50.0   EARNEDINCOME       5.668118e+07
#        EARNEDINCOME2      7.146791e+07
#        FREELANCER         4.606854e+07
#        OTHERINCOME        4.151192e+07
#        PRACTITIONER       7.271631e+07
#        PRIVATEBUSINESS    7.681174e+07
# 60.0   EARNEDINCOME       4.237836e+07
#        EARNEDINCOME2      3.771044e+07
#        FREELANCER         4.745902e+07
#        OTHERINCOME        4.082302e+07
#        PRACTITIONER       8.622244e+07
#        PRIVATEBUSINESS    7.535626e+07
# 70.0   EARNEDINCOME       3.400600e+07
#        EARNEDINCOME2      3.629583e+07
#        FREELANCER         2.571562e+07
#        OTHERINCOME        2.737281e+07
#        PRACTITIONER       3.214286e+07
#        PRIVATEBUSINESS    7.631183e+07
# Name: yearly_income, dtype: float64

# %%
user_spec = user_spec.fillna({'yearly_income': 0})

# %%
user_spec[user_spec['application_id'] == 2045613]
# Out:
#         application_id  user_id  birth_year  gender          insert_time  \
# 233316         2045613   702899      1995.0     1.0  2022-06-30 18:37:04
#
#         credit_score  yearly_income income_type  company_enter_month  \
# 233316         520.0            0.0  FREELANCER           20220630.0
#
#        employment_type houseown_type  desired_amount       purpose  \
# 233316              기타           전월세       5000000.0  HOUSEDEPOSIT
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 233316                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt   age  reage
# 233316                1.0          1000000.0  28.0   20.0

# %%
index = user_spec[user_spec['application_id'] == 2045613].index
index
# Out:
# Int64Index([233316], dtype='int64')

# %%
user_spec.iat[233305, 6] = 27482640

# %%
user_spec[user_spec['application_id'] == 2045613]
# Out:
#         application_id  user_id  birth_year  gender          insert_time  \
# 233316         2045613   702899      1995.0     1.0  2022-06-30 18:37:04
#
#         credit_score  yearly_income income_type  company_enter_month  \
# 233316         520.0     27482640.0  FREELANCER           20220630.0
#
#        employment_type houseown_type  desired_amount       purpose  \
# 233316              기타           전월세       5000000.0  HOUSEDEPOSIT
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 233316                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt   age  reage
# 233316                1.0          1000000.0  28.0   20.0

# %%
user_spec.isnull().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12959
# gender                                   12959
# insert_time                                  0
# credit_score                            105112
# yearly_income                                0
# income_type                                  0
# company_enter_month                     171675
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn              587376
# personal_rehabilitation_complete_yn    1203269
# existing_loan_cnt                       198540
# existing_loan_amt                       313752
# age                                      12959
# reage                                    12959
# dtype: int64

# %% [markdown]
# # 4. existing_loan_cnt 결측값

# %%
user_spec_2 = user_spec.fillna({'existing_loan_cnt': 'NaN'})
user_spec_2[user_spec_2['existing_loan_cnt'] == 'NaN']
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 7               1146166   588743      1992.0     0.0  2022-06-07 17:19:33
# 23              1237618   717213      1986.0     1.0  2022-06-07 03:26:54
# 25               272600   754046      1980.0     1.0  2022-06-07 19:24:28
# 37               703129   324991      1994.0     0.0  2022-06-07 11:12:24
# 48               612258    59149      1998.0     1.0  2022-06-07 07:31:21
# ...                 ...      ...         ...     ...                  ...
# 1394184         1107103   162983      1978.0     1.0  2022-03-22 12:14:17
# 1394203          943512   183117      1996.0     0.0  2022-03-22 16:22:21
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 7               750.0     46000000.0     EARNEDINCOME           20151001.0
# 23              530.0     51000000.0     EARNEDINCOME           20170501.0
# 25                NaN     22000000.0     EARNEDINCOME           20090101.0
# 37              950.0            0.0      OTHERINCOME                  NaN
# 48                NaN            0.0  PRIVATEBUSINESS           20220301.0
# ...               ...            ...              ...                  ...
# 1394184         750.0     55000000.0     EARNEDINCOME             201408.0
# 1394203         710.0     24000000.0     EARNEDINCOME             202201.0
# 1394204         710.0     30000000.0      OTHERINCOME                  NaN
# 1394211         590.0     25000000.0       FREELANCER             202106.0
# 1394215           NaN     35000000.0       FREELANCER             201103.0
#
#         employment_type houseown_type  desired_amount       purpose  \
# 7                   정규직        기타가족소유       6000000.0        LIVING
# 23                  정규직           전월세       5000000.0        LIVING
# 25                  정규직           전월세      22000000.0    SWITCHLOAN
# 37                   기타            자가      50000000.0           ETC
# 48                   기타           전월세       1000000.0        LIVING
# ...                 ...           ...             ...           ...
# 1394184             정규직           전월세      50000000.0        LIVING
# 1394203             정규직           전월세      25000000.0  HOUSEDEPOSIT
# 1394204              기타           전월세      25000000.0           ETC
# 1394211              기타        기타가족소유       5000000.0      BUSINESS
# 1394215              기타            자가      20000000.0        LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 7                               0.0                                  0.0
# 23                              0.0                                  0.0
# 25                              0.0                                  NaN
# 37                              0.0                                  NaN
# 48                              0.0                                  0.0
# ...                             ...                                  ...
# 1394184                         NaN                                  NaN
# 1394203                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394211                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#         existing_loan_cnt  existing_loan_amt   age  reage
# 7                     NaN                NaN  31.0   30.0
# 23                    NaN                NaN  37.0   30.0
# 25                    NaN                NaN  43.0   40.0
# 37                    NaN                NaN  29.0   20.0
# 48                    NaN                NaN  25.0   20.0
# ...                   ...                ...   ...    ...
# 1394184               NaN                NaN  45.0   40.0
# 1394203               NaN                NaN  27.0   20.0
# 1394204               NaN                NaN  27.0   20.0
# 1394211               NaN                NaN  23.0   20.0
# 1394215               NaN                NaN  46.0   40.0
#
# [198540 rows x 19 columns]

# %%
user_spec['existing_loan_cnt'].unique()
# Out:
# array([  4.,   1.,   5.,   7.,  nan,   3.,   2.,  10.,   6.,   8.,  14.,
#          9.,  15.,  12.,  11.,  22.,  13.,  21.,  32.,  44.,  23.,  16.,
#         17.,  18.,  25.,  70.,  20.,  24.,  76.,  50.,  27.,  35.,  48.,
#         19.,  40.,  38.,  29.,  79.,  41.,  33.,  31.,  84.,  45.,  37.,
#         26.,  30.,  28.,  43.,  34.,  97., 109.,  39.,  58.,  65.,  42.,
#         86., 103.,  60.,  63.,  59.,  55.,  46., 102., 178.,  53.,  36.,
#         51.,  54., 131.,  47.,  49., 157.,  89.,  52.,  62.,  57.,  56.,
#         66.,  74., 117., 107.,  61., 125.,  69.,  96.,  77.,  75., 142.,
#         85., 229.,  81., 278., 176.,  72., 128.,  73., 106.,  67.,  71.,
#        169., 156.])

# %% [markdown]
# * 기대출 수에 0 은 존재하고 있지 않고, 198540명 정도는 처음으로 대출상품을 이용하는 고객일 가능성이 높다 생각해 existing_loan_cnt의 결측값은 0으로 채우기

# %%
user_spec = user_spec.fillna({'existing_loan_cnt': 0})

# %%
user_spec.isnull().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12959
# gender                                   12959
# insert_time                                  0
# credit_score                            105112
# yearly_income                                0
# income_type                                  0
# company_enter_month                     171675
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn              587376
# personal_rehabilitation_complete_yn    1203269
# existing_loan_cnt                            0
# existing_loan_amt                       313752
# age                                      12959
# reage                                    12959
# dtype: int64

# %% [markdown]
# # 5. existing_loan_amt 결측값

# %%
plt.figure(figsize=(30,8))
sns.distplot(user_spec['existing_loan_amt'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * 분위수 2~3 의 평균만

# %% [markdown]
# * 기대출 수가 0인 부분은 0으로 채우고 나머지는.. 최빈값?

# %%
test = user_spec[user_spec['existing_loan_amt'] >= 1000000000]
test
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 712             1887738    32395      1975.0     1.0  2022-03-19 15:13:42
# 3139            1233080    87327      1973.0     1.0  2022-06-07 14:49:35
# 4468             163956   529880      1985.0     1.0  2022-03-25 11:28:28
# 6448             811182   755640      1970.0     1.0  2022-04-25 11:10:05
# 10555            754108   510213      1973.0     1.0  2022-06-14 20:31:08
# ...                 ...      ...         ...     ...                  ...
# 1355089         1086225   679240      1974.0     1.0  2022-05-20 16:49:46
# 1379170         1297831    52341      1982.0     0.0  2022-06-22 12:16:43
# 1379656         1741693   222663      1977.0     1.0  2022-04-27 13:01:22
# 1381666         1066122   222663      1977.0     1.0  2022-06-10 20:58:14
# 1386527          442266   841691      1979.0     1.0  2022-03-08 20:51:27
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 712             850.0    250000000.0  PRIVATEBUSINESS             200702.0
# 3139            810.0     78000000.0     EARNEDINCOME           19960901.0
# 4468            650.0     45000000.0     EARNEDINCOME             201103.0
# 6448            360.0     15000000.0     EARNEDINCOME             200909.0
# 10555           700.0     43000000.0     EARNEDINCOME           20120101.0
# ...               ...            ...              ...                  ...
# 1355089           NaN    150000000.0     EARNEDINCOME             200301.0
# 1379170         650.0     60000000.0     EARNEDINCOME           20210701.0
# 1379656         650.0    320000000.0     EARNEDINCOME             201804.0
# 1381666         650.0    320000000.0     PRACTITIONER           20180401.0
# 1386527         940.0     50000000.0      OTHERINCOME                  NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 712                 정규직            자가      30000000.0      LIVING
# 3139                정규직            자가      50000000.0         ETC
# 4468                정규직            자가      10000000.0      LIVING
# 6448                정규직            자가      20000000.0      LIVING
# 10555               정규직            자가      40000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1355089             정규직            자가      60000000.0      LIVING
# 1379170             정규직            자가      40000000.0  SWITCHLOAN
# 1379656             정규직           전월세     200000000.0         ETC
# 1381666             정규직        기타가족소유     300000000.0      LIVING
# 1386527              기타            자가      30000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 712                             NaN                                  NaN
# 3139                            0.0                                  0.0
# 4468                            NaN                                  NaN
# 6448                            0.0                                  NaN
# 10555                           0.0                                  NaN
# ...                             ...                                  ...
# 1355089                         0.0                                  0.0
# 1379170                         0.0                                  NaN
# 1379656                         0.0                                  NaN
# 1381666                         0.0                                  NaN
# 1386527                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 712                    4.0       1.234000e+09  48.0   40.0
# 3139                   4.0       1.068000e+09  50.0   50.0
# 4468                   6.0       1.134000e+09  38.0   30.0
# 6448                  10.0       1.196000e+09  53.0   50.0
# 10555                 11.0       1.066000e+09  50.0   50.0
# ...                    ...                ...   ...    ...
# 1355089               19.0       1.045000e+09  49.0   40.0
# 1379170                4.0       1.107000e+09  41.0   40.0
# 1379656                4.0       1.074000e+09  46.0   40.0
# 1381666                4.0       1.074000e+09  46.0   40.0
# 1386527                3.0       1.820000e+09  44.0   40.0
#
# [402 rows x 19 columns]

# %% [markdown]
# # 6. 파생변수 아이디어 살짝

# %% [markdown]
# * existing_loan_amt / existing_loan_cnt	 = 과거 대출 1회 당 평균 금액
# * 과거 대출 1회 당 대출 금액과 desired_amount의 차이 (많냐 적냐/ 차이금액)
# * 기존 대출 없었던 사람은 동일로 봄

# %% [markdown]
# # 7. 입사년도 연도로만 통일화

# %%
user_spec.loc[(user_spec['company_enter_month'] < 10000000)]
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# ...                 ...      ...         ...     ...                  ...
# 1394210          316356    53701      1996.0     1.0  2022-03-22 10:01:38
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2             202110.0
# 154             590.0     50000000.0  PRIVATEBUSINESS             201211.0
# 155             600.0    100000000.0  PRIVATEBUSINESS             201210.0
# 156             730.0     95000000.0     EARNEDINCOME             201803.0
# 157             670.0     35000000.0     EARNEDINCOME             201901.0
# ...               ...            ...              ...                  ...
# 1394210         730.0     60000000.0  PRIVATEBUSINESS             202105.0
# 1394211         590.0     25000000.0       FREELANCER             202106.0
# 1394213         750.0     75000000.0     EARNEDINCOME             200908.0
# 1394214         640.0     50000000.0     EARNEDINCOME             201705.0
# 1394215           NaN     35000000.0       FREELANCER             201103.0
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# ...                 ...           ...             ...         ...
# 1394210             정규직           전월세      15000000.0    BUSINESS
# 1394211              기타        기타가족소유       5000000.0    BUSINESS
# 1394213             정규직            자가     100000000.0  SWITCHLOAN
# 1394214             정규직            자가      10000000.0  SWITCHLOAN
# 1394215              기타            자가      20000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 155                             NaN                                  NaN
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# ...                             ...                                  ...
# 1394210                         NaN                                  NaN
# 1394211                         NaN                                  NaN
# 1394213                         NaN                                  NaN
# 1394214                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 155                    1.0         14000000.0  47.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# ...                    ...                ...   ...    ...
# 1394210                1.0                NaN  27.0   20.0
# 1394211                0.0                NaN  23.0   20.0
# 1394213                8.0        200000000.0  40.0   40.0
# 1394214               10.0        117000000.0  48.0   40.0
# 1394215                0.0                NaN  46.0   40.0
#
# [921469 rows x 19 columns]

# %%
user_spec.loc[(user_spec['company_enter_month'] > 10000000)]
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394083         2154350    28718      1994.0     1.0  2022-06-21 10:51:16
# 1394084          759813   659656      1990.0     0.0  2022-06-21 14:25:07
# 1394086          242374   293080      1983.0     1.0  2022-06-21 21:13:54
# 1394087         1356506    50945      1982.0     1.0  2022-06-21 09:07:48
# 1394088         1247601   558807      1997.0     1.0  2022-06-21 10:10:57
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS           20151101.0
# 1               870.0     30000000.0  PRIVATEBUSINESS           20070201.0
# 2               710.0     30000000.0       FREELANCER           20210901.0
# 3               820.0     62000000.0     EARNEDINCOME           20170101.0
# 4               630.0     36000000.0     EARNEDINCOME           20210901.0
# ...               ...            ...              ...                  ...
# 1394083         590.0     40000000.0     EARNEDINCOME           20210301.0
# 1394084         600.0     34000000.0     EARNEDINCOME           20211014.0
# 1394086         660.0     78000000.0     EARNEDINCOME           20200501.0
# 1394087         560.0     34000000.0     EARNEDINCOME           20201001.0
# 1394088         650.0     44000000.0    EARNEDINCOME2           20220401.0
#
#         employment_type houseown_type  desired_amount     purpose  \
# 0                    기타            자가       1000000.0         ETC
# 1                   정규직        기타가족소유      30000000.0  SWITCHLOAN
# 2                    기타        기타가족소유      10000000.0      LIVING
# 3                   정규직            자가       2000000.0      LIVING
# 4                   정규직        기타가족소유       5000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1394083             계약직           전월세       3000000.0      LIVING
# 1394084             정규직        기타가족소유       1000000.0      LIVING
# 1394086             정규직            자가      30000000.0      LIVING
# 1394087             정규직           전월세       4000000.0      LIVING
# 1394088             계약직           전월세      30000000.0  SWITCHLOAN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                               0.0                                  NaN
# 1                               0.0                                  NaN
# 2                               0.0                                  NaN
# 3                               0.0                                  NaN
# 4                               0.0                                  0.0
# ...                             ...                                  ...
# 1394083                         0.0                                  0.0
# 1394084                         0.0                                  0.0
# 1394086                         0.0                                  NaN
# 1394087                         0.0                                  NaN
# 1394088                         0.0                                  0.0
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 0                      4.0        162000000.0  38.0   30.0
# 1                      1.0         27000000.0  55.0   50.0
# 2                      5.0         15000000.0  26.0   20.0
# 3                      7.0        344000000.0  34.0   30.0
# 4                      1.0         16000000.0  23.0   20.0
# ...                    ...                ...   ...    ...
# 1394083                8.0         73000000.0  29.0   20.0
# 1394084                5.0         46000000.0  33.0   30.0
# 1394086                3.0        202000000.0  40.0   40.0
# 1394087                5.0         65000000.0  41.0   40.0
# 1394088                5.0         22000000.0  26.0   20.0
#
# [300987 rows x 19 columns]

# %%
user_spec_test = user_spec.fillna({'company_enter_month': 'NaN'})

# %%
user_spec_0 = user_spec_test[user_spec_test['company_enter_month'] == 'NaN']

# %%
user_spec_1 = user_spec[user_spec['company_enter_month'] < 10000000]
user_spec_1['company_enter_month'] = (user_spec_1['company_enter_month'] / 100).round()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
user_spec_2 = user_spec[user_spec['company_enter_month'] >= 10000000]
user_spec_2['company_enter_month'] = (user_spec_2['company_enter_month'] / 10000).round()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test = pd.concat([user_spec_1, user_spec_2])
test
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# ...                 ...      ...         ...     ...                  ...
# 1394083         2154350    28718      1994.0     1.0  2022-06-21 10:51:16
# 1394084          759813   659656      1990.0     0.0  2022-06-21 14:25:07
# 1394086          242374   293080      1983.0     1.0  2022-06-21 21:13:54
# 1394087         1356506    50945      1982.0     1.0  2022-06-21 09:07:48
# 1394088         1247601   558807      1997.0     1.0  2022-06-21 10:10:57
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2               2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS               2012.0
# 155             600.0    100000000.0  PRIVATEBUSINESS               2012.0
# 156             730.0     95000000.0     EARNEDINCOME               2018.0
# 157             670.0     35000000.0     EARNEDINCOME               2019.0
# ...               ...            ...              ...                  ...
# 1394083         590.0     40000000.0     EARNEDINCOME               2021.0
# 1394084         600.0     34000000.0     EARNEDINCOME               2021.0
# 1394086         660.0     78000000.0     EARNEDINCOME               2020.0
# 1394087         560.0     34000000.0     EARNEDINCOME               2020.0
# 1394088         650.0     44000000.0    EARNEDINCOME2               2022.0
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# ...                 ...           ...             ...         ...
# 1394083             계약직           전월세       3000000.0      LIVING
# 1394084             정규직        기타가족소유       1000000.0      LIVING
# 1394086             정규직            자가      30000000.0      LIVING
# 1394087             정규직           전월세       4000000.0      LIVING
# 1394088             계약직           전월세      30000000.0  SWITCHLOAN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 155                             NaN                                  NaN
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# ...                             ...                                  ...
# 1394083                         0.0                                  0.0
# 1394084                         0.0                                  0.0
# 1394086                         0.0                                  NaN
# 1394087                         0.0                                  NaN
# 1394088                         0.0                                  0.0
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 155                    1.0         14000000.0  47.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# ...                    ...                ...   ...    ...
# 1394083                8.0         73000000.0  29.0   20.0
# 1394084                5.0         46000000.0  33.0   30.0
# 1394086                3.0        202000000.0  40.0   40.0
# 1394087                5.0         65000000.0  41.0   40.0
# 1394088                5.0         22000000.0  26.0   20.0
#
# [1222456 rows x 19 columns]

# %%
plt.figure(figsize=(30,8))
sns.distplot(test['company_enter_month'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * 많은 사람이이 2021 쯤인걸로 봐서 가장 최근 직장 입사일 기준인 것 같음

# %%
user_spec = pd.concat([test, user_spec_0])
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 155             600.0    100000000.0  PRIVATEBUSINESS              2012.0
# 156             730.0     95000000.0     EARNEDINCOME              2018.0
# 157             670.0     35000000.0     EARNEDINCOME              2019.0
# ...               ...            ...              ...                 ...
# 1394139         560.0     35000000.0      OTHERINCOME                 NaN
# 1394174         520.0     20000000.0      OTHERINCOME                 NaN
# 1394194         760.0     32000000.0      OTHERINCOME                 NaN
# 1394204         710.0     30000000.0      OTHERINCOME                 NaN
# 1394212         980.0     20000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 155                             NaN                                  NaN
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# ...                             ...                                  ...
# 1394139                         NaN                                  NaN
# 1394174                         NaN                                  NaN
# 1394194                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394212                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 155                    1.0         14000000.0  47.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [1394131 rows x 19 columns]

# %%
plt.figure(figsize=(30,8))
sns.countplot(user_spec['company_enter_month'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
user_spec[user_spec['company_enter_month'] == 'NaN']
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 6               1614045   860410      1976.0     1.0  2022-06-07 11:29:05
# 26               696416   648540      1965.0     1.0  2022-06-07 11:38:46
# 37               703129   324991      1994.0     0.0  2022-06-07 11:12:24
# 39               246114   470525      1983.0     1.0  2022-06-07 22:00:53
# 45               531087   260981      1976.0     1.0  2022-06-07 11:34:55
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income  income_type company_enter_month  \
# 6               590.0     45000000.0  OTHERINCOME                 NaN
# 26              750.0     30000000.0  OTHERINCOME                 NaN
# 37              950.0            0.0  OTHERINCOME                 NaN
# 39                NaN     45000000.0  OTHERINCOME                 NaN
# 45              680.0     42000000.0  OTHERINCOME                 NaN
# ...               ...            ...          ...                 ...
# 1394139         560.0     35000000.0  OTHERINCOME                 NaN
# 1394174         520.0     20000000.0  OTHERINCOME                 NaN
# 1394194         760.0     32000000.0  OTHERINCOME                 NaN
# 1394204         710.0     30000000.0  OTHERINCOME                 NaN
# 1394212         980.0     20000000.0  OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 6                    기타            자가      15000000.0  SWITCHLOAN
# 26                   기타           전월세      20000000.0      LIVING
# 37                   기타            자가      50000000.0         ETC
# 39                   기타           전월세      30000000.0    BUSINESS
# 45                   기타            자가       6000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 6                               0.0                                  NaN
# 26                              0.0                                  NaN
# 37                              0.0                                  NaN
# 39                              0.0                                  NaN
# 45                              0.0                                  NaN
# ...                             ...                                  ...
# 1394139                         NaN                                  NaN
# 1394174                         NaN                                  NaN
# 1394194                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394212                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 6                      1.0         20000000.0  47.0   40.0
# 26                     1.0                NaN  58.0   50.0
# 37                     0.0                NaN  29.0   20.0
# 39                     1.0                NaN  40.0   40.0
# 45                    15.0         42000000.0  47.0   40.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [171675 rows x 19 columns]

# %% [markdown]
# * 19살 이하

# %%
a = user_spec[user_spec['age']<=19]
a
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 94319           1451310   636531      2004.0     0.0  2022-05-14 00:15:08
# 182244          2049432   141632      2004.0     1.0  2022-05-17 23:18:53
# 377474           459489    43128      2005.0     1.0  2022-03-14 00:29:47
# 426583          1403690   806320      2007.0     1.0  2022-05-28 11:18:30
# 479147          1898508   446404      2006.0     1.0  2022-04-18 01:16:52
# ...                 ...      ...         ...     ...                  ...
# 1275895         2142945   425345      2005.0     1.0  2022-06-23 01:32:10
# 1325718         1374844   680641      2006.0     1.0  2022-05-12 10:09:56
# 1343326         1953877   595174      2005.0     0.0  2022-05-01 15:31:49
# 1348307         1931824   511507      2004.0     0.0  2022-06-26 09:55:25
# 1381935         1501915   755520      2004.0     1.0  2022-05-27 16:45:25
#
#          credit_score  yearly_income    income_type company_enter_month  \
# 94319           750.0      2000000.0   EARNEDINCOME              2021.0
# 182244            NaN     14000000.0     FREELANCER              2022.0
# 377474            NaN     40000000.0  EARNEDINCOME2              2021.0
# 426583            NaN     40000000.0     FREELANCER              2022.0
# 479147            NaN     80000000.0  EARNEDINCOME2              2022.0
# ...               ...            ...            ...                 ...
# 1275895           NaN      1000000.0    OTHERINCOME                 NaN
# 1325718           NaN            0.0    OTHERINCOME                 NaN
# 1343326           NaN            0.0    OTHERINCOME                 NaN
# 1348307           NaN            0.0    OTHERINCOME                 NaN
# 1381935           NaN      1000000.0    OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount       purpose  \
# 94319               정규직           전월세             0.0        LIVING
# 182244               기타        기타가족소유       3000000.0           ETC
# 377474               기타           전월세       2000000.0      BUSINESS
# 426583               기타        기타가족소유     200000000.0      BUSINESS
# 479147              계약직        기타가족소유       6000000.0        LIVING
# ...                 ...           ...             ...           ...
# 1275895              기타            자가       5000000.0        LIVING
# 1325718              기타        기타가족소유             0.0        LIVING
# 1343326              기타        기타가족소유             0.0        LIVING
# 1348307              기타           전월세     100000000.0  HOUSEDEPOSIT
# 1381935              기타        기타가족소유       1000000.0           ETC
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 94319                           0.0                                  NaN
# 182244                          1.0                                  1.0
# 377474                          NaN                                  NaN
# 426583                          0.0                                  NaN
# 479147                          NaN                                  NaN
# ...                             ...                                  ...
# 1275895                         0.0                                  NaN
# 1325718                         0.0                                  0.0
# 1343326                         0.0                                  NaN
# 1348307                         0.0                                  0.0
# 1381935                         0.0                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 94319                  1.0                NaN  19.0   10.0
# 182244                 1.0                NaN  19.0   10.0
# 377474                 0.0                NaN  18.0   10.0
# 426583                 1.0                NaN  16.0   10.0
# 479147                 1.0                NaN  17.0   10.0
# ...                    ...                ...   ...    ...
# 1275895                1.0                NaN  18.0   10.0
# 1325718                0.0                NaN  17.0   10.0
# 1343326                1.0                NaN  18.0   10.0
# 1348307                0.0                NaN  19.0   10.0
# 1381935                1.0                NaN  19.0   10.0
#
# [114 rows x 19 columns]

# %%
# 데이터 불러오기
loan_result = pd.read_csv('/content/gdrive/MyDrive/dataset/loan_result.csv')
loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied
# 0         42000000.0       13.6         NaN
# 1         24000000.0       17.9         NaN
# 2         24000000.0       18.5         NaN
# 3         29000000.0       10.8         NaN
# 4          5000000.0       16.4         NaN
# ...              ...        ...         ...
# 13527358   3000000.0       14.8         NaN
# 13527359  40000000.0       11.8         NaN
# 13527360  15000000.0        7.2         NaN
# 13527361  44000000.0       13.5         NaN
# 13527362  44000000.0        9.7         NaN
#
# [13527363 rows x 7 columns]

# %%
merge1 = pd.merge(loan_result, a,
                    how = 'left',
                    on = 'application_id')
merge1
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 0         42000000.0       13.6         NaN      NaN         NaN     NaN  ...
# 1         24000000.0       17.9         NaN      NaN         NaN     NaN  ...
# 2         24000000.0       18.5         NaN      NaN         NaN     NaN  ...
# 3         29000000.0       10.8         NaN      NaN         NaN     NaN  ...
# 4          5000000.0       16.4         NaN      NaN         NaN     NaN  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 13527358   3000000.0       14.8         NaN      NaN         NaN     NaN  ...
# 13527359  40000000.0       11.8         NaN      NaN         NaN     NaN  ...
# 13527360  15000000.0        7.2         NaN      NaN         NaN     NaN  ...
# 13527361  44000000.0       13.5         NaN      NaN         NaN     NaN  ...
# 13527362  44000000.0        9.7         NaN      NaN         NaN     NaN  ...
#
#          employment_type  houseown_type  desired_amount purpose  \
# 0                    NaN            NaN             NaN     NaN
# 1                    NaN            NaN             NaN     NaN
# 2                    NaN            NaN             NaN     NaN
# 3                    NaN            NaN             NaN     NaN
# 4                    NaN            NaN             NaN     NaN
# ...                  ...            ...             ...     ...
# 13527358             NaN            NaN             NaN     NaN
# 13527359             NaN            NaN             NaN     NaN
# 13527360             NaN            NaN             NaN     NaN
# 13527361             NaN            NaN             NaN     NaN
# 13527362             NaN            NaN             NaN     NaN
#
#          personal_rehabilitation_yn personal_rehabilitation_complete_yn  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# ...                             ...                                 ...
# 13527358                        NaN                                 NaN
# 13527359                        NaN                                 NaN
# 13527360                        NaN                                 NaN
# 13527361                        NaN                                 NaN
# 13527362                        NaN                                 NaN
#
#          existing_loan_cnt  existing_loan_amt age  reage
# 0                      NaN                NaN NaN    NaN
# 1                      NaN                NaN NaN    NaN
# 2                      NaN                NaN NaN    NaN
# 3                      NaN                NaN NaN    NaN
# 4                      NaN                NaN NaN    NaN
# ...                    ...                ...  ..    ...
# 13527358               NaN                NaN NaN    NaN
# 13527359               NaN                NaN NaN    NaN
# 13527360               NaN                NaN NaN    NaN
# 13527361               NaN                NaN NaN    NaN
# 13527362               NaN                NaN NaN    NaN
#
# [13527363 rows x 25 columns]

# %%
b = merge1[merge1['age'].notnull()]
b
# Out:
# Empty DataFrame
# Columns: [application_id, loanapply_insert_time, bank_id, product_id, loan_limit, loan_rate, is_applied, user_id, birth_year, gender, insert_time, credit_score, yearly_income, income_type, company_enter_month, employment_type, houseown_type, desired_amount, purpose, personal_rehabilitation_yn, personal_rehabilitation_complete_yn, existing_loan_cnt, existing_loan_amt, age, reage]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# * 19살 이하가 대출한 사람이 없음 확인

# %%
test.groupby(['reage'])['company_enter_month'].mean()
# Out:
# reage
# 10.0    2020.631579
# 20.0    2020.694502
# 30.0    2019.139347
# 40.0    2017.019879
# 50.0    2015.655749
# 60.0    2016.701267
# 70.0    2016.859967
# Name: company_enter_month, dtype: float64

# %% [markdown]
# * 나이대 별로 회사 입사 년도 평균 넣기(반올림)

# %% [markdown]
# # 8. 회사입사 연도, 태어난 연도 차이로 근속연수 파생변수 만들기

# %% [markdown]
# # 9. 성별

# %%
user_spec["gender"].value_counts()
# Out:
# 1.0    934267
# 0.0    446905
# Name: gender, dtype: int64

# %%
user_spec.groupby(['gender']).mean()
# Out:
#         application_id        user_id   birth_year  credit_score  \
# gender
# 0.0       1.084339e+06  438033.147826  1982.233855    634.601276
# 1.0       1.083929e+06  440267.879030  1983.787821    640.031380
#
#         yearly_income  desired_amount  personal_rehabilitation_yn  \
# gender
# 0.0      3.749489e+07    2.651393e+07                    0.016309
# 1.0      4.634174e+07    3.211161e+07                    0.015334
#
#         personal_rehabilitation_complete_yn  existing_loan_cnt  \
# gender
# 0.0                                0.006640           4.031450
# 1.0                                0.007253           4.107391
#
#         existing_loan_amt        age      reage
# gender
# 0.0          5.733741e+07  40.766145  36.327631
# 1.0          7.717286e+07  39.212179  34.782594

# %% [markdown]
# * 비율대로 무작위 넣는게 최선일 것 같은 느낌

# %% [markdown]
# # 남은 것

# %% [markdown]
# * personal_rehabilitation_yn              587376
# * personal_rehabilitation_complete_yn    1203269
# * credit_score                            105112

# %% [markdown]
# # 9/20 personal_rehabilitation_yn

# %%
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 155             600.0    100000000.0  PRIVATEBUSINESS              2012.0
# 156             730.0     95000000.0     EARNEDINCOME              2018.0
# 157             670.0     35000000.0     EARNEDINCOME              2019.0
# ...               ...            ...              ...                 ...
# 1394139         560.0     35000000.0      OTHERINCOME                 NaN
# 1394174         520.0     20000000.0      OTHERINCOME                 NaN
# 1394194         760.0     32000000.0      OTHERINCOME                 NaN
# 1394204         710.0     30000000.0      OTHERINCOME                 NaN
# 1394212         980.0     20000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 155                             NaN                                  NaN
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# ...                             ...                                  ...
# 1394139                         NaN                                  NaN
# 1394174                         NaN                                  NaN
# 1394194                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394212                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 155                    1.0         14000000.0  47.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [1394131 rows x 19 columns]

# %%
user_spec['personal_rehabilitation_yn'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
user_spec['personal_rehabilitation_yn'].value_counts()
# Out:
# 0.0    794046
# 1.0     12709
# Name: personal_rehabilitation_yn, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(user_spec['personal_rehabilitation_yn'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
user_spec.groupby(['personal_rehabilitation_yn']).count()
# Out:
#                             application_id  user_id  birth_year  gender  \
# personal_rehabilitation_yn
# 0.0                                 794046   794046      786127  786127
# 1.0                                  12709    12709       12501   12501
#
#                             insert_time  credit_score  yearly_income  \
# personal_rehabilitation_yn
# 0.0                              794046        745802         794046
# 1.0                               12709         11340          12709
#
#                             income_type  company_enter_month  employment_type  \
# personal_rehabilitation_yn
# 0.0                              794046               794046           794046
# 1.0                               12709                12709            12709
#
#                             houseown_type  desired_amount  purpose  \
# personal_rehabilitation_yn
# 0.0                                794046          794046   794046
# 1.0                                 12709           12709    12709
#
#                             personal_rehabilitation_complete_yn  \
# personal_rehabilitation_yn
# 0.0                                                      178153
# 1.0                                                       12709
#
#                             existing_loan_cnt  existing_loan_amt     age  \
# personal_rehabilitation_yn
# 0.0                                    794046             634908  786127
# 1.0                                     12709               8537   12501
#
#                              reage
# personal_rehabilitation_yn
# 0.0                         786127
# 1.0                          12501

# %% [markdown]
# * 794046 : 12709

# %%
user_spec[user_spec['personal_rehabilitation_yn'] == 0]
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# 158             1355252   180240      1995.0     0.0  2022-04-20 15:21:40
# ...                 ...      ...         ...     ...                  ...
# 1394007         1636169   671866      1935.0     0.0  2022-06-21 08:26:07
# 1394011          275848   294140      1976.0     0.0  2022-06-21 09:38:27
# 1394042         1167939   737948      1996.0     0.0  2022-06-21 23:53:29
# 1394072         1088308   821383      1984.0     0.0  2022-06-21 19:40:15
# 1394085         2138480   848568      1995.0     1.0  2022-06-21 14:55:00
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 156             730.0     95000000.0     EARNEDINCOME              2018.0
# 157             670.0     35000000.0     EARNEDINCOME              2019.0
# 158             930.0     31000000.0     EARNEDINCOME              2022.0
# ...               ...            ...              ...                 ...
# 1394007         590.0      6000000.0      OTHERINCOME                 NaN
# 1394011         570.0     36000000.0      OTHERINCOME                 NaN
# 1394042         820.0            0.0      OTHERINCOME                 NaN
# 1394072         760.0     20000000.0      OTHERINCOME                 NaN
# 1394085         620.0     25000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# 158                 정규직           전월세      50000000.0    BUYHOUSE
# ...                 ...           ...             ...         ...
# 1394007              기타            자가       3000000.0      LIVING
# 1394011              기타           전월세       3000000.0      LIVING
# 1394042              기타        기타가족소유       3000000.0      LIVING
# 1394072              기타           전월세      25000000.0  SWITCHLOAN
# 1394085              기타           전월세       3000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# 158                             0.0                                  0.0
# ...                             ...                                  ...
# 1394007                         0.0                                  NaN
# 1394011                         0.0                                  NaN
# 1394042                         0.0                                  0.0
# 1394072                         0.0                                  NaN
# 1394085                         0.0                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# 158                    0.0                NaN  28.0   20.0
# ...                    ...                ...   ...    ...
# 1394007                2.0         25000000.0  88.0   70.0
# 1394011                6.0         63000000.0  47.0   40.0
# 1394042                1.0                NaN  27.0   20.0
# 1394072                3.0         44000000.0  39.0   30.0
# 1394085                1.0          3000000.0  28.0   20.0
#
# [794046 rows x 19 columns]

# %% [markdown]
# ### 정의서에 나온 설명 그대로 쓴 것
# * 0: 개인회생자X, 1: 개인회생자O
# * 0: (개인회생자인 경우) 납입중, 1: 납입완료

# %% [markdown]
# * 개인 회생자 O -> 개인회생자 납입 완료 여부 O/X : 1 -> 0/1
# * 개인 회생자 X -> 개인회생자 납입 이미 끝남/ 개인회생자 된 적 없음: 0 -> NaN (이렇게 되어야하는데 개인회상자 아닌데 개인회생 납입중인 사람으로 표현된 사람들은 뭐지? 오류인듯)

# %%
user_spec[user_spec['personal_rehabilitation_yn'] == 1]
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 170             1640338   298318      1976.0     1.0  2022-04-20 08:16:04
# 224              256442   614734      1976.0     1.0  2022-04-20 16:13:06
# 839             1317819   153202      1986.0     1.0  2022-04-24 13:15:11
# 940             1508331   490410      1976.0     1.0  2022-05-31 10:27:56
# 953             1283327   115321      1990.0     1.0  2022-05-31 12:24:13
# ...                 ...      ...         ...     ...                  ...
# 1391808         1150217   669120      1971.0     0.0  2022-06-23 11:06:33
# 1392073          272266   717275      1982.0     0.0  2022-05-25 12:13:07
# 1392539         1204274   516963      1996.0     0.0  2022-05-12 18:57:17
# 1392834          903515   355781      1971.0     0.0  2022-06-14 19:02:54
# 1393103         1703638   414806      1972.0     1.0  2022-05-29 13:04:02
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 170             100.0     50000000.0     EARNEDINCOME              2014.0
# 224             540.0     40000000.0     EARNEDINCOME              2019.0
# 839             250.0     30000000.0  PRIVATEBUSINESS              2020.0
# 940             600.0     35000000.0     EARNEDINCOME              2022.0
# 953             580.0     55000000.0     EARNEDINCOME              2016.0
# ...               ...            ...              ...                 ...
# 1391808         550.0     20000000.0      OTHERINCOME                 NaN
# 1392073         100.0     50000000.0      OTHERINCOME                 NaN
# 1392539           NaN            0.0      OTHERINCOME                 NaN
# 1392834         550.0     18000000.0      OTHERINCOME                 NaN
# 1393103         100.0     35000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount purpose  \
# 170                 정규직           전월세       5000000.0  LIVING
# 224                 정규직           전월세      15000000.0  LIVING
# 839                 계약직        기타가족소유       1000000.0  LIVING
# 940                 정규직        기타가족소유       3000000.0  LIVING
# 953                 정규직        기타가족소유       5000000.0  LIVING
# ...                 ...           ...             ...     ...
# 1391808              기타        기타가족소유       4000000.0  LIVING
# 1392073              기타           전월세       3000000.0  LIVING
# 1392539              기타        기타가족소유      10000000.0  LIVING
# 1392834              기타        기타가족소유       4000000.0  LIVING
# 1393103              기타        기타가족소유       2000000.0  LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 170                             1.0                                  0.0
# 224                             1.0                                  0.0
# 839                             1.0                                  0.0
# 940                             1.0                                  0.0
# 953                             1.0                                  1.0
# ...                             ...                                  ...
# 1391808                         1.0                                  0.0
# 1392073                         1.0                                  0.0
# 1392539                         1.0                                  0.0
# 1392834                         1.0                                  0.0
# 1393103                         1.0                                  0.0
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 170                    1.0         25000000.0  47.0   40.0
# 224                    2.0         64000000.0  47.0   40.0
# 839                    5.0         37000000.0  37.0   30.0
# 940                    2.0          9000000.0  47.0   40.0
# 953                    3.0         67000000.0  33.0   30.0
# ...                    ...                ...   ...    ...
# 1391808                2.0         28000000.0  52.0   50.0
# 1392073                1.0          4000000.0  41.0   40.0
# 1392539                0.0                NaN  27.0   20.0
# 1392834                6.0         28000000.0  52.0   50.0
# 1393103                1.0                NaN  51.0   50.0
#
# [12709 rows x 19 columns]

# %%
sns.boxplot(y= user_spec["credit_score"], x=user_spec["personal_rehabilitation_yn"])

# %% [markdown]
# * 신용점수가 400이하인 것은 개인회생여부 1
# * 나머지 결측값(신용점수가 결측값이라 못 채우는 것도 포함)은 0: 1 =  794046 : 12709 비율로 랜덤 --> 400이하인 것은 1로 만든걸 감안해서 0쪽에 살짝 더 비율을 줘도 될 것 같아 깔끔하게 0:1 = 80:12 로

# %% [markdown]
# 신용점수가 과연 개인회생여부에 가장 큰 의미를 부여하는 변수인가...?

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = user_spec.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')

# %% [markdown]
# 성아님이 말한거 코드로 넣어보기

# %%
user_spec['personal_rehabilitation_yn'].isnull().sum()
# Out:
# 587376

# %%
pry_spec=user_spec[user_spec['personal_rehabilitation_yn'].isnull()]
pry_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 159             1232849   575347      1982.0     1.0  2022-04-20 11:49:52
# 160              675491   848534      1984.0     1.0  2022-04-20 15:44:42
# 162              867828   126213      1984.0     1.0  2022-04-20 11:07:41
# 164              821862    75798      1971.0     0.0  2022-04-20 15:21:23
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 155             600.0    100000000.0  PRIVATEBUSINESS              2012.0
# 159             620.0     48000000.0     EARNEDINCOME              2022.0
# 160             580.0     50000000.0     EARNEDINCOME              2020.0
# 162             850.0     60000000.0     EARNEDINCOME              2017.0
# 164             520.0     65000000.0    EARNEDINCOME2              2016.0
# ...               ...            ...              ...                 ...
# 1394139         560.0     35000000.0      OTHERINCOME                 NaN
# 1394174         520.0     20000000.0      OTHERINCOME                 NaN
# 1394194         760.0     32000000.0      OTHERINCOME                 NaN
# 1394204         710.0     30000000.0      OTHERINCOME                 NaN
# 1394212         980.0     20000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 159                 계약직           전월세       5000000.0      LIVING
# 160                 정규직           전월세      50000000.0      LIVING
# 162                 정규직           전월세      30000000.0      LIVING
# 164                  기타           전월세       5000000.0         ETC
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 155                             NaN                                  NaN
# 159                             NaN                                  NaN
# 160                             NaN                                  NaN
# 162                             NaN                                  NaN
# 164                             NaN                                  NaN
# ...                             ...                                  ...
# 1394139                         NaN                                  NaN
# 1394174                         NaN                                  NaN
# 1394194                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394212                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 155                    1.0         14000000.0  47.0   40.0
# 159                    1.0                NaN  41.0   40.0
# 160                    5.0         71000000.0  39.0   30.0
# 162                    8.0        138000000.0  39.0   30.0
# 164                    1.0         28000000.0  52.0   50.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [587376 rows x 19 columns]

# %% [markdown]
# 위 데이터에서 신용점수 400이하 추출

# %%
pry_spec_1=pry_spec[pry_spec['credit_score']<=400]

# %%
pry_spec_1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 392              479935   761774      1970.0     0.0  2022-03-06 20:09:13
# 399              727366    86953      1958.0     1.0  2022-03-06 15:06:10
# 703              305601   619588      1976.0     1.0  2022-03-19 15:53:49
# 912             1980548   549237      2000.0     0.0  2022-03-19 17:21:44
# 1025            1463105   169138      1990.0     1.0  2022-03-29 18:36:12
# ...                 ...      ...         ...     ...                  ...
# 1389205          373515   744252      1977.0     0.0  2022-03-11 17:01:37
# 1390002         1241937   666224      1970.0     1.0  2022-03-15 07:03:45
# 1393616         2150800   614132      1951.0     1.0  2022-04-27 17:41:35
# 1394101          236265   859254      1966.0     1.0  2022-03-22 15:50:13
# 1394102          230428   859254      1966.0     1.0  2022-03-22 18:09:31
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 392             100.0     24000000.0     EARNEDINCOME              2020.0
# 399             100.0     20000000.0     EARNEDINCOME              2020.0
# 703             250.0     20000000.0     EARNEDINCOME              2021.0
# 912             250.0     15000000.0  PRIVATEBUSINESS              2021.0
# 1025            100.0     36000000.0     EARNEDINCOME              2019.0
# ...               ...            ...              ...                 ...
# 1389205         380.0     20000000.0      OTHERINCOME                 NaN
# 1390002         250.0     30000000.0      OTHERINCOME                 NaN
# 1393616         250.0      8000000.0      OTHERINCOME                 NaN
# 1394101         150.0     40000000.0      OTHERINCOME                 NaN
# 1394102         150.0     40000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount       purpose  \
# 392                 정규직        기타가족소유      20000000.0    SWITCHLOAN
# 399                 계약직           전월세      10000000.0  HOUSEDEPOSIT
# 703                 계약직           전월세      10000000.0        LIVING
# 912                  기타           전월세      20000000.0      BUSINESS
# 1025                정규직        기타가족소유       5000000.0        LIVING
# ...                 ...           ...             ...           ...
# 1389205              기타            자가       5000000.0        LIVING
# 1390002              기타           전월세      10000000.0        LIVING
# 1393616              기타        기타가족소유      30000000.0        INVEST
# 1394101              기타           전월세      50000000.0    SWITCHLOAN
# 1394102              기타        기타가족소유      30000000.0    SWITCHLOAN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 392                             NaN                                  NaN
# 399                             NaN                                  NaN
# 703                             NaN                                  NaN
# 912                             NaN                                  NaN
# 1025                            NaN                                  NaN
# ...                             ...                                  ...
# 1389205                         NaN                                  NaN
# 1390002                         NaN                                  NaN
# 1393616                         NaN                                  NaN
# 1394101                         NaN                                  NaN
# 1394102                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 392                    2.0         42000000.0  53.0   50.0
# 399                    1.0                NaN  65.0   60.0
# 703                    1.0         15000000.0  47.0   40.0
# 912                    3.0          4000000.0  23.0   20.0
# 1025                   1.0         36000000.0  33.0   30.0
# ...                    ...                ...   ...    ...
# 1389205                4.0        273000000.0  46.0   40.0
# 1390002                1.0                NaN  53.0   50.0
# 1393616                1.0                NaN  72.0   70.0
# 1394101                2.0         23000000.0  57.0   50.0
# 1394102                2.0         23000000.0  57.0   50.0
#
# [9406 rows x 19 columns]

# %%
pry_spec['personal_rehabilitation_yn'] = pry_spec_1['personal_rehabilitation_yn'].fillna(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pry_spec['personal_rehabilitation_yn'].isnull().sum()
# Out:
# 577970

# %% [markdown]
# 나머지 결측값(신용점수가 결측값이라 못 채우는 것도 포함)은 0: 1 = 794046 : 12709 비율로 랜덤 --> 400이하인 것은 1로 만든걸 감안해서 0쪽에 살짝 더 비율을 줘도 될 것 같아 깔끔하게 0:1 = 80:12 로

# %% [markdown]
# 98.45:1.55 -> 98:2
# 이비율로 넣을까...? 아님 변수간의 관계를 통해서 넣는 합리적 접근법을 사용할까 하지만 이는 변수간의 관계가 확실하지가 않아서 사용 못할듯...

# %% [markdown]
# ### 결측치 간의 상관관계를 확인하기

# %%
import missingno as msno
user_null = user_spec.columns[user_spec.isnull().any()].tolist()
msno.heatmap(user_spec[user_null], figsize=(8,6))
plt.title("Correlation with Missing Values", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation with Missing Values')

# %% [markdown]
# 결측값간의 관계를 확인해봤지만 아무런 인사이트를 얻을수 없다고 판단...

# %% [markdown]
# - 무작위적으로 샘플링해서 값을 임의로 넣어도 나쁘지 않을것 같다...?

# %%
df=user_spec[user_spec['personal_rehabilitation_yn'].isnull()]
df_sample = df.sample(n=569011, random_state=100)
df_sample
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 95015           1616090   287827      1984.0     1.0  2022-03-08 02:38:31
# 899694          1342613   408291      1992.0     1.0  2022-03-14 14:33:34
# 600545            46690     7355      1979.0     1.0  2022-04-09 22:41:19
# 161951          2018855   510129      1970.0     0.0  2022-04-16 22:37:12
# 128004          1604346   782299      1997.0     1.0  2022-03-07 15:51:54
# ...                 ...      ...         ...     ...                  ...
# 665861           885219   554018      1989.0     1.0  2022-03-28 11:13:02
# 329763           534470   533096      1972.0     1.0  2022-04-24 16:41:35
# 331307           982538   114520      1979.0     0.0  2022-03-24 09:20:02
# 1036659           59190   356327      1965.0     0.0  2022-03-10 13:39:41
# 1374278          168403   343829      1984.0     1.0  2022-03-21 07:01:20
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 95015           950.0     40000000.0  PRIVATEBUSINESS              2012.0
# 899694          580.0     33000000.0     EARNEDINCOME              2020.0
# 600545          680.0     28000000.0     EARNEDINCOME              2018.0
# 161951          700.0     30000000.0     EARNEDINCOME              2021.0
# 128004          500.0     60000000.0       FREELANCER              2021.0
# ...               ...            ...              ...                 ...
# 665861          640.0     37000000.0     EARNEDINCOME              2019.0
# 329763          820.0     80000000.0     EARNEDINCOME              2020.0
# 331307          580.0     36000000.0     EARNEDINCOME              2019.0
# 1036659         530.0     90000000.0       FREELANCER              2019.0
# 1374278         610.0    120000000.0     EARNEDINCOME              2011.0
#
#         employment_type houseown_type  desired_amount     purpose  \
# 95015               정규직            자가      20000000.0    BUSINESS
# 899694              정규직            자가      10000000.0      LIVING
# 600545              정규직        기타가족소유      10000000.0      LIVING
# 161951              정규직        기타가족소유      35000000.0  SWITCHLOAN
# 128004               기타        기타가족소유      10000000.0  SWITCHLOAN
# ...                 ...           ...             ...         ...
# 665861              정규직           전월세       1000000.0      LIVING
# 329763              정규직            자가     100000000.0    BUSINESS
# 331307              정규직        기타가족소유      10000000.0  SWITCHLOAN
# 1036659              기타        기타가족소유      30000000.0  SWITCHLOAN
# 1374278             정규직           전월세      20000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 95015                           NaN                                  NaN
# 899694                          NaN                                  NaN
# 600545                          NaN                                  NaN
# 161951                          NaN                                  NaN
# 128004                          NaN                                  NaN
# ...                             ...                                  ...
# 665861                          NaN                                  NaN
# 329763                          NaN                                  NaN
# 331307                          NaN                                  NaN
# 1036659                         NaN                                  NaN
# 1374278                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 95015                  4.0        195000000.0  39.0   30.0
# 899694                 7.0         94000000.0  31.0   30.0
# 600545                 7.0         62000000.0  44.0   40.0
# 161951                 6.0         58000000.0  53.0   50.0
# 128004                 4.0         25000000.0  26.0   20.0
# ...                    ...                ...   ...    ...
# 665861                 6.0         63000000.0  34.0   30.0
# 329763                 1.0          3000000.0  51.0   50.0
# 331307                 5.0         76000000.0  44.0   40.0
# 1036659                2.0         14000000.0  58.0   50.0
# 1374278                6.0        167000000.0  39.0   30.0
#
# [569011 rows x 19 columns]

# %%
pry_spec['personal_rehabilitation_yn'] = df_sample['personal_rehabilitation_yn'].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pry_spec['personal_rehabilitation_yn'].isnull().sum()
# Out:
# 18365

# %%
pry_spec['personal_rehabilitation_yn'] = pry_spec['personal_rehabilitation_yn'].fillna(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pry_spec['personal_rehabilitation_yn'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 9/20 personal_rehabilitation_complete_yn

# %% [markdown]
# 1. 개인회생 0 -> 완료 0 으로 되어있는 사람은 오류라 판단해서 N으로 바꾸기

# %%
pr_0 = user_spec['personal_rehabilitation_yn'] == 0
prc_0 = user_spec['personal_rehabilitation_complete_yn'] == 0

subset = user_spec[pr_0 & prc_0]
subset
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 158             1355252   180240      1995.0     0.0  2022-04-20 15:21:40
# 172             1806891   866473      1986.0     0.0  2022-04-20 17:09:36
# 178              997513   641399      1991.0     0.0  2022-04-20 18:35:07
# ...                 ...      ...         ...     ...                  ...
# 1393605          325289   350747      1988.0     0.0  2022-04-27 16:20:15
# 1393809         2167614    86260      1990.0     0.0  2022-05-21 14:31:55
# 1393864          447450   152794      1989.0     0.0  2022-05-21 02:27:48
# 1393898         1762801   792309      2001.0     1.0  2022-06-26 10:56:22
# 1394042         1167939   737948      1996.0     0.0  2022-06-21 23:53:29
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 158             930.0     31000000.0     EARNEDINCOME              2022.0
# 172             630.0     48000000.0     EARNEDINCOME              2008.0
# 178             560.0     25000000.0     EARNEDINCOME              2021.0
# ...               ...            ...              ...                 ...
# 1393605           NaN     23000000.0      OTHERINCOME                 NaN
# 1393809         570.0     60000000.0      OTHERINCOME                 NaN
# 1393864         600.0     20000000.0      OTHERINCOME                 NaN
# 1393898           NaN            0.0      OTHERINCOME                 NaN
# 1394042         820.0            0.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 158                 정규직           전월세      50000000.0    BUYHOUSE
# 172                 정규직        기타가족소유      90000000.0  SWITCHLOAN
# 178                 정규직        기타가족소유       3000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1393605              기타            자가      50000000.0  SWITCHLOAN
# 1393809              기타        기타가족소유       5000000.0         ETC
# 1393864              기타           전월세      15000000.0  SWITCHLOAN
# 1393898              기타        기타가족소유       2000000.0      LIVING
# 1394042              기타        기타가족소유       3000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 153                             0.0                                  0.0
# 154                             0.0                                  0.0
# 158                             0.0                                  0.0
# 172                             0.0                                  0.0
# 178                             0.0                                  0.0
# ...                             ...                                  ...
# 1393605                         0.0                                  0.0
# 1393809                         0.0                                  0.0
# 1393864                         0.0                                  0.0
# 1393898                         0.0                                  0.0
# 1394042                         0.0                                  0.0
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 158                    0.0                NaN  28.0   20.0
# 172                    1.0                NaN  37.0   30.0
# 178                    0.0                NaN  32.0   30.0
# ...                    ...                ...   ...    ...
# 1393605                1.0        236000000.0  35.0   30.0
# 1393809               12.0         23000000.0  33.0   30.0
# 1393864                3.0         18000000.0  34.0   30.0
# 1393898                0.0                NaN  22.0   20.0
# 1394042                1.0                NaN  27.0   20.0
#
# [178149 rows x 19 columns]

# %%
subset['personal_rehabilitation_complete_yn'] =subset['personal_rehabilitation_complete_yn'].replace(0, 'N')
subset
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 158             1355252   180240      1995.0     0.0  2022-04-20 15:21:40
# 172             1806891   866473      1986.0     0.0  2022-04-20 17:09:36
# 178              997513   641399      1991.0     0.0  2022-04-20 18:35:07
# ...                 ...      ...         ...     ...                  ...
# 1393605          325289   350747      1988.0     0.0  2022-04-27 16:20:15
# 1393809         2167614    86260      1990.0     0.0  2022-05-21 14:31:55
# 1393864          447450   152794      1989.0     0.0  2022-05-21 02:27:48
# 1393898         1762801   792309      2001.0     1.0  2022-06-26 10:56:22
# 1394042         1167939   737948      1996.0     0.0  2022-06-21 23:53:29
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 158             930.0     31000000.0     EARNEDINCOME              2022.0
# 172             630.0     48000000.0     EARNEDINCOME              2008.0
# 178             560.0     25000000.0     EARNEDINCOME              2021.0
# ...               ...            ...              ...                 ...
# 1393605           NaN     23000000.0      OTHERINCOME                 NaN
# 1393809         570.0     60000000.0      OTHERINCOME                 NaN
# 1393864         600.0     20000000.0      OTHERINCOME                 NaN
# 1393898           NaN            0.0      OTHERINCOME                 NaN
# 1394042         820.0            0.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 158                 정규직           전월세      50000000.0    BUYHOUSE
# 172                 정규직        기타가족소유      90000000.0  SWITCHLOAN
# 178                 정규직        기타가족소유       3000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1393605              기타            자가      50000000.0  SWITCHLOAN
# 1393809              기타        기타가족소유       5000000.0         ETC
# 1393864              기타           전월세      15000000.0  SWITCHLOAN
# 1393898              기타        기타가족소유       2000000.0      LIVING
# 1394042              기타        기타가족소유       3000000.0      LIVING
#
#          personal_rehabilitation_yn personal_rehabilitation_complete_yn  \
# 153                             0.0                                   N
# 154                             0.0                                   N
# 158                             0.0                                   N
# 172                             0.0                                   N
# 178                             0.0                                   N
# ...                             ...                                 ...
# 1393605                         0.0                                   N
# 1393809                         0.0                                   N
# 1393864                         0.0                                   N
# 1393898                         0.0                                   N
# 1394042                         0.0                                   N
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 158                    0.0                NaN  28.0   20.0
# 172                    1.0                NaN  37.0   30.0
# 178                    0.0                NaN  32.0   30.0
# ...                    ...                ...   ...    ...
# 1393605                1.0        236000000.0  35.0   30.0
# 1393809               12.0         23000000.0  33.0   30.0
# 1393864                3.0         18000000.0  34.0   30.0
# 1393898                0.0                NaN  22.0   20.0
# 1394042                1.0                NaN  27.0   20.0
#
# [178149 rows x 19 columns]

# %%
pr_1 = user_spec['personal_rehabilitation_yn'] != 0
prc_1 = user_spec['personal_rehabilitation_complete_yn'] != 0

subset1 = user_spec[pr_1 | prc_1]
subset1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 155             1617530   379488      1976.0     1.0  2022-04-20 10:08:40
# 156             1019382   186886      1979.0     1.0  2022-04-20 00:38:18
# 157             1117343   594274      1993.0     0.0  2022-04-20 15:01:01
# 159             1232849   575347      1982.0     1.0  2022-04-20 11:49:52
# 160              675491   848534      1984.0     1.0  2022-04-20 15:44:42
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 155             600.0    100000000.0  PRIVATEBUSINESS              2012.0
# 156             730.0     95000000.0     EARNEDINCOME              2018.0
# 157             670.0     35000000.0     EARNEDINCOME              2019.0
# 159             620.0     48000000.0     EARNEDINCOME              2022.0
# 160             580.0     50000000.0     EARNEDINCOME              2020.0
# ...               ...            ...              ...                 ...
# 1394139         560.0     35000000.0      OTHERINCOME                 NaN
# 1394174         520.0     20000000.0      OTHERINCOME                 NaN
# 1394194         760.0     32000000.0      OTHERINCOME                 NaN
# 1394204         710.0     30000000.0      OTHERINCOME                 NaN
# 1394212         980.0     20000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 155                 정규직        기타가족소유      10000000.0      LIVING
# 156                 정규직           전월세      40000000.0  SWITCHLOAN
# 157                 정규직           전월세      13000000.0  SWITCHLOAN
# 159                 계약직           전월세       5000000.0      LIVING
# 160                 정규직           전월세      50000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 155                             NaN                                  NaN
# 156                             0.0                                  NaN
# 157                             0.0                                  NaN
# 159                             NaN                                  NaN
# 160                             NaN                                  NaN
# ...                             ...                                  ...
# 1394139                         NaN                                  NaN
# 1394174                         NaN                                  NaN
# 1394194                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394212                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 155                    1.0         14000000.0  47.0   40.0
# 156                    4.0        142000000.0  44.0   40.0
# 157                    3.0         36000000.0  30.0   30.0
# 159                    1.0                NaN  41.0   40.0
# 160                    5.0         71000000.0  39.0   30.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [1215982 rows x 19 columns]

# %%
user_spec = pd.concat([subset, subset1])
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 153             1945260   836762      1979.0     1.0  2022-04-20 01:23:09
# 154             1384503     8623      1979.0     0.0  2022-04-20 18:51:40
# 158             1355252   180240      1995.0     0.0  2022-04-20 15:21:40
# 172             1806891   866473      1986.0     0.0  2022-04-20 17:09:36
# 178              997513   641399      1991.0     0.0  2022-04-20 18:35:07
# ...                 ...      ...         ...     ...                  ...
# 1394139          889505   564698      1973.0     1.0  2022-03-22 10:04:18
# 1394174         1108793   374260      1994.0     1.0  2022-03-22 03:59:57
# 1394194          834323   145747      1958.0     1.0  2022-03-22 18:10:29
# 1394204         1663661   183117      1996.0     0.0  2022-03-22 17:37:49
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 153             670.0     50000000.0    EARNEDINCOME2              2021.0
# 154             590.0     50000000.0  PRIVATEBUSINESS              2012.0
# 158             930.0     31000000.0     EARNEDINCOME              2022.0
# 172             630.0     48000000.0     EARNEDINCOME              2008.0
# 178             560.0     25000000.0     EARNEDINCOME              2021.0
# ...               ...            ...              ...                 ...
# 1394139         560.0     35000000.0      OTHERINCOME                 NaN
# 1394174         520.0     20000000.0      OTHERINCOME                 NaN
# 1394194         760.0     32000000.0      OTHERINCOME                 NaN
# 1394204         710.0     30000000.0      OTHERINCOME                 NaN
# 1394212         980.0     20000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount     purpose  \
# 153                  기타           전월세      25000000.0  SWITCHLOAN
# 154                 정규직            자가      50000000.0    BUSINESS
# 158                 정규직           전월세      50000000.0    BUYHOUSE
# 172                 정규직        기타가족소유      90000000.0  SWITCHLOAN
# 178                 정규직        기타가족소유       3000000.0      LIVING
# ...                 ...           ...             ...         ...
# 1394139              기타        기타가족소유       3000000.0      LIVING
# 1394174              기타        기타가족소유      10000000.0  SWITCHLOAN
# 1394194              기타            자가     100000000.0  SWITCHLOAN
# 1394204              기타           전월세      25000000.0         ETC
# 1394212              기타            자가      50000000.0      LIVING
#
#          personal_rehabilitation_yn personal_rehabilitation_complete_yn  \
# 153                             0.0                                   N
# 154                             0.0                                   N
# 158                             0.0                                   N
# 172                             0.0                                   N
# 178                             0.0                                   N
# ...                             ...                                 ...
# 1394139                         NaN                                 NaN
# 1394174                         NaN                                 NaN
# 1394194                         NaN                                 NaN
# 1394204                         NaN                                 NaN
# 1394212                         NaN                                 NaN
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 153                    3.0         76000000.0  44.0   40.0
# 154                    0.0                NaN  44.0   40.0
# 158                    0.0                NaN  28.0   20.0
# 172                    1.0                NaN  37.0   30.0
# 178                    0.0                NaN  32.0   30.0
# ...                    ...                ...   ...    ...
# 1394139                5.0         13000000.0  50.0   50.0
# 1394174                0.0                NaN  29.0   20.0
# 1394194                2.0         31000000.0  65.0   60.0
# 1394204                0.0                NaN  27.0   20.0
# 1394212                1.0                NaN  68.0   60.0
#
# [1394131 rows x 19 columns]

# %% [markdown]
# 2. 나머지 결측값 채우기

# %%
user_spec.groupby(['personal_rehabilitation_complete_yn']).mean()
# Out:
#                                      application_id        user_id  \
# personal_rehabilitation_complete_yn
# 0.0                                    1.092102e+06  442385.101047
# 1.0                                    1.071573e+06  459080.598373
# N                                      1.084988e+06  437817.653857
#
#                                       birth_year    gender  credit_score  \
# personal_rehabilitation_complete_yn
# 0.0                                  1981.547527  0.662166    442.790422
# 1.0                                  1982.290469  0.633888    501.925566
# N                                    1990.186874  0.609882    641.751217
#
#                                      yearly_income  desired_amount  \
# personal_rehabilitation_complete_yn
# 0.0                                   4.083848e+07    3.108248e+07
# 1.0                                   4.036095e+07    3.883358e+07
# N                                     3.761884e+07    2.681881e+07
#
#                                      personal_rehabilitation_yn  \
# personal_rehabilitation_complete_yn
# 0.0                                                    1.000000
# 1.0                                                    0.997041
# N                                                      0.000000
#
#                                      existing_loan_cnt  existing_loan_amt  \
# personal_rehabilitation_complete_yn
# 0.0                                           2.174456       3.339738e+07
# 1.0                                           1.877959       3.673455e+07
# N                                             3.580789       5.969330e+07
#
#                                            age      reage
# personal_rehabilitation_complete_yn
# 0.0                                  41.452473  37.075919
# 1.0                                  40.709531  36.248109
# N                                    32.813126  28.320439

# %%
sns.boxplot(y= user_spec["credit_score"], x=user_spec["personal_rehabilitation_complete_yn"])

# %%
plt.figure(figsize=(10,8))
sns.countplot(user_spec['personal_rehabilitation_complete_yn'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
t = user_spec['personal_rehabilitation_yn'] == 0
tt = user_spec['personal_rehabilitation_complete_yn'] == 1

ttt = user_spec[t & tt]
ttt
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 94465           1574646    39991      1981.0     0.0  2022-04-21 13:14:59
# 139885          1065260   598997      1988.0     1.0  2022-05-17 19:42:47
# 1319216         1624053    24030      1981.0     1.0  2022-05-13 00:23:08
# 84244           1501280   855482      2002.0     1.0  2022-06-06 21:01:14
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 94465           600.0     22000000.0     EARNEDINCOME              2017.0
# 139885            NaN     15000000.0  PRIVATEBUSINESS              2017.0
# 1319216         650.0     32000000.0     EARNEDINCOME              2022.0
# 84244             NaN      1000000.0      OTHERINCOME                 NaN
#
#         employment_type houseown_type  desired_amount purpose  \
# 94465               계약직           전월세       4000000.0  LIVING
# 139885               기타           전월세      10000000.0  LIVING
# 1319216             정규직        기타가족소유       5000000.0  LIVING
# 84244                기타        기타가족소유             0.0  LIVING
#
#          personal_rehabilitation_yn personal_rehabilitation_complete_yn  \
# 94465                           0.0                                 1.0
# 139885                          0.0                                 1.0
# 1319216                         0.0                                 1.0
# 84244                           0.0                                 1.0
#
#          existing_loan_cnt  existing_loan_amt   age  reage
# 94465                  1.0                NaN  42.0   40.0
# 139885                 0.0                NaN  35.0   30.0
# 1319216                1.0          3000000.0  42.0   40.0
# 84244                  0.0                NaN  21.0   20.0

# %% [markdown]
# * 개인회생자가 아닌데 개인회생납입 완료인 사람은 과거에 납입 완료해서 현재는 개인회생자가 아닌걸로 뵈야하나

# %% [markdown]
# * 개인회생자가 0인 사람은 개인회생납부 중인거는 말이 안되고, 개인회생납부 완료자는 4명밖에 없고 거의 대부분이 N 이므로 개인회생납부완료의 결측값은 N으로 채우기
# * 개인회생자가 1인 사람은 신용점수 600이상은 1, 나머지는 0으로 채우기
