# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# 데이터 불러오기
loan_spec_log = pd.read_csv('/Users/sungahwang/Desktop/BigContest_data/loan_spec_log.csv')
loan_spec_log
# Out:
#           application_id  bank_id  product_id  loan_limit  loan_rate  \
# 0                1748340        7         191  42000000.0       13.6
# 1                1748340       25         169  24000000.0       17.9
# 2                1748340        2           7  24000000.0       18.5
# 3                1748340        4         268  29000000.0       10.8
# 4                1748340       11         118   5000000.0       16.4
# ...                  ...      ...         ...         ...        ...
# 13525488         1969227        2           7  30000000.0       13.6
# 13525489         1969227       33         110   9000000.0       14.4
# 13525490         1969227       50         142   3000000.0       11.2
# 13525491         1969227       22         100   4000000.0       15.3
# 13525492         1969227       19         231   9000000.0       15.5
#
#           is_applied  weekday  loanapply_insert_hour   user_id  gender  ...  \
# 0                NaN  Tuesday                     13  430982.0     1.0  ...
# 1                NaN  Tuesday                     13  430982.0     1.0  ...
# 2                NaN  Tuesday                     13  430982.0     1.0  ...
# 3                NaN  Tuesday                     13  430982.0     1.0  ...
# 4                NaN  Tuesday                     13  430982.0     1.0  ...
# ...              ...      ...                    ...       ...     ...  ...
# 13525488         0.0   Monday                     14  109899.0     1.0  ...
# 13525489         0.0   Monday                     14  109899.0     1.0  ...
# 13525490         0.0   Monday                     14  109899.0     1.0  ...
# 13525491         0.0   Monday                     14  109899.0     1.0  ...
# 13525492         0.0   Monday                     14  109899.0     1.0  ...
#
#          existing_loan_cnt  existing_loan_amt reage career credit_grade  \
# 0                      2.0         15000000.0  20.0    1.0          7.0
# 1                      2.0         15000000.0  20.0    1.0          7.0
# 2                      2.0         15000000.0  20.0    1.0          7.0
# 3                      2.0         15000000.0  20.0    1.0          7.0
# 4                      2.0         15000000.0  20.0    1.0          7.0
# ...                    ...                ...   ...    ...          ...
# 13525488               9.0        107000000.0  40.0    2.0          7.0
# 13525489               9.0        107000000.0  40.0    2.0          7.0
# 13525490               9.0        107000000.0  40.0    2.0          7.0
# 13525491               9.0        107000000.0  40.0    2.0          7.0
# 13525492               9.0        107000000.0  40.0    2.0          7.0
#
#           spec_clust action_cnt  use_day_cnt   first_event  timeout_sum(s)
# 0                2.0      176.0         17.0  EndLoanApply           201.0
# 1                2.0      176.0         17.0  EndLoanApply           201.0
# 2                2.0      176.0         17.0  EndLoanApply           201.0
# 3                2.0      176.0         17.0  EndLoanApply           201.0
# 4                2.0      176.0         17.0  EndLoanApply           201.0
# ...              ...        ...          ...           ...             ...
# 13525488         4.0      178.0         27.0  EndLoanApply           350.0
# 13525489         4.0      178.0         27.0  EndLoanApply           350.0
# 13525490         4.0      178.0         27.0  EndLoanApply           350.0
# 13525491         4.0      178.0         27.0  EndLoanApply           350.0
# 13525492         4.0      178.0         27.0  EndLoanApply           350.0
#
# [13525493 rows x 29 columns]

# %%
clust = loan_spec_log[['spec_clust', 'bank_id', 'product_id']]
clust.head(3)
# Out:
#    spec_clust  bank_id  product_id
# 0         2.0        7         191
# 1         2.0       25         169
# 2         2.0        2           7

# %%
clust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13525493 entries, 0 to 13525492
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   spec_clust  float64
#  1   bank_id     int64
#  2   product_id  int64
# dtypes: float64(1), int64(2)
# memory usage: 309.6 MB

# %% [markdown]
# # K-Modes (범주형 군집분석 방법)

# %%
clust = loan_spec_log[['spec_clust', 'bank_id', 'product_id']]
clust.head(3)
# Out:
#    spec_clust  bank_id  product_id
# 0         2.0        7         191
# 1         2.0       25         169
# 2         2.0        2           7

# %%
clust['spec_clust'] = clust['spec_clust'].astype(str)
# Out:
# /var/folders/8s/_473l8ss1hx20zy1txdh03x40000gn/T/ipykernel_52909/1027929861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust['spec_clust'] = clust['spec_clust'].astype(str)

# %%
clust['bank_id'] = clust['bank_id'].astype(str)
# Out:
# /var/folders/8s/_473l8ss1hx20zy1txdh03x40000gn/T/ipykernel_52909/847526272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust['bank_id'] = clust['bank_id'].astype(str)

# %%
clust['product_id'] = clust['product_id'].astype(str)
# Out:
# /var/folders/8s/_473l8ss1hx20zy1txdh03x40000gn/T/ipykernel_52909/3667646038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust['product_id'] = clust['product_id'].astype(str)

# %%
clust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13525493 entries, 0 to 13525492
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   spec_clust  object
#  1   bank_id     object
#  2   product_id  object
# dtypes: object(3)
# memory usage: 309.6+ MB

# %%
from kmodes.kmodes import KModes

# %% [markdown]
# ##

# %%
cost = []
K = range(1,10)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 2, verbose=True)
    kmode.fit_predict(clust)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 34367776.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 34367776.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 220327, cost: 31460029.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 33835299.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 506713, cost: 29354215.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 295220, cost: 29264214.0
# Run 2, iteration: 2/100, moves: 275649, cost: 29185646.0
# Run 2, iteration: 3/100, moves: 179217, cost: 29185646.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 319681, cost: 28932256.0
# Run 1, iteration: 2/100, moves: 103783, cost: 28932256.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 209079, cost: 31167119.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 372456, cost: 28644390.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 428667, cost: 28357702.0
# Run 2, iteration: 2/100, moves: 3115, cost: 28357702.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 482178, cost: 26831019.0
# Run 1, iteration: 2/100, moves: 95486, cost: 26831019.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2257029, cost: 26882561.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 552790, cost: 29621465.0
# Run 1, iteration: 2/100, moves: 3953, cost: 29621465.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 767260, cost: 26393008.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2071127, cost: 26520190.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 4469091, cost: 25014729.0
# Run 2, iteration: 2/100, moves: 23499, cost: 25014729.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 792125, cost: 24775724.0
# Run 1, iteration: 2/100, moves: 281658, cost: 24726260.0
# Run 1, iteration: 3/100, moves: 58058, cost: 24726260.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2362853, cost: 25676011.0
# Run 2, iteration: 2/100, moves: 186421, cost: 25676011.0
# Best run was number 1

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ##

# %%
kmode = KModes(n_clusters=6, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(clust)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2064916, cost: 28429437.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 344007, cost: 27190153.0
# Run 2, iteration: 2/100, moves: 4543, cost: 27190153.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2542713, cost: 26762823.0
# Run 3, iteration: 2/100, moves: 361991, cost: 26629672.0
# Run 3, iteration: 3/100, moves: 9208, cost: 26629672.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 710495, cost: 26513195.0
# Run 4, iteration: 2/100, moves: 1428, cost: 26513195.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 813467, cost: 28369241.0
# Run 5, iteration: 2/100, moves: 76158, cost: 28369241.0
# Best run was number 4
# array([4, 4, 4, ..., 0, 0, 0], dtype=uint16)

# %%
labels  = kmode.labels_

# %%
loan_spec_log['cluster2'] = labels

# %%
loan_spec_log
# Out:
#           application_id  bank_id  product_id  loan_limit  loan_rate  \
# 0                1748340        7         191  42000000.0       13.6
# 1                1748340       25         169  24000000.0       17.9
# 2                1748340        2           7  24000000.0       18.5
# 3                1748340        4         268  29000000.0       10.8
# 4                1748340       11         118   5000000.0       16.4
# ...                  ...      ...         ...         ...        ...
# 13525488         1969227        2           7  30000000.0       13.6
# 13525489         1969227       33         110   9000000.0       14.4
# 13525490         1969227       50         142   3000000.0       11.2
# 13525491         1969227       22         100   4000000.0       15.3
# 13525492         1969227       19         231   9000000.0       15.5
#
#           is_applied  weekday  loanapply_insert_hour   user_id  gender  ...  \
# 0                NaN  Tuesday                     13  430982.0     1.0  ...
# 1                NaN  Tuesday                     13  430982.0     1.0  ...
# 2                NaN  Tuesday                     13  430982.0     1.0  ...
# 3                NaN  Tuesday                     13  430982.0     1.0  ...
# 4                NaN  Tuesday                     13  430982.0     1.0  ...
# ...              ...      ...                    ...       ...     ...  ...
# 13525488         0.0   Monday                     14  109899.0     1.0  ...
# 13525489         0.0   Monday                     14  109899.0     1.0  ...
# 13525490         0.0   Monday                     14  109899.0     1.0  ...
# 13525491         0.0   Monday                     14  109899.0     1.0  ...
# 13525492         0.0   Monday                     14  109899.0     1.0  ...
#
#          existing_loan_amt  reage career credit_grade spec_clust  action_cnt  \
# 0               15000000.0   20.0    1.0          7.0        2.0       176.0
# 1               15000000.0   20.0    1.0          7.0        2.0       176.0
# 2               15000000.0   20.0    1.0          7.0        2.0       176.0
# 3               15000000.0   20.0    1.0          7.0        2.0       176.0
# 4               15000000.0   20.0    1.0          7.0        2.0       176.0
# ...                    ...    ...    ...          ...        ...         ...
# 13525488       107000000.0   40.0    2.0          7.0        4.0       178.0
# 13525489       107000000.0   40.0    2.0          7.0        4.0       178.0
# 13525490       107000000.0   40.0    2.0          7.0        4.0       178.0
# 13525491       107000000.0   40.0    2.0          7.0        4.0       178.0
# 13525492       107000000.0   40.0    2.0          7.0        4.0       178.0
#
#          use_day_cnt   first_event  timeout_sum(s)  cluster2
# 0               17.0  EndLoanApply           201.0         4
# 1               17.0  EndLoanApply           201.0         4
# 2               17.0  EndLoanApply           201.0         4
# 3               17.0  EndLoanApply           201.0         4
# 4               17.0  EndLoanApply           201.0         5
# ...              ...           ...             ...       ...
# 13525488        27.0  EndLoanApply           350.0         0
# 13525489        27.0  EndLoanApply           350.0         2
# 13525490        27.0  EndLoanApply           350.0         0
# 13525491        27.0  EndLoanApply           350.0         0
# 13525492        27.0  EndLoanApply           350.0         0
#
# [13525493 rows x 30 columns]

# %%
cluster1 = loan_spec_log[loan_spec_log['cluster2']==0]
cluster2 = loan_spec_log[loan_spec_log['cluster2']==1]
cluster3 = loan_spec_log[loan_spec_log['cluster2']==2]
cluster4 = loan_spec_log[loan_spec_log['cluster2']==3]
cluster5 = loan_spec_log[loan_spec_log['cluster2']==4]

# %%
ax=sns.countplot(x=loan_spec_log.cluster2)
for index, row in pd.DataFrame(loan_spec_log['cluster2'].value_counts()).iterrows():
    ax.text(index,row.values[0], str(round(row.values[0])),color='black', ha="center")
    print(index,row.values[0])
plt.title('Cluster Count')
plt.show()
# Out:
# 1 5054843
# 0 3646734
# 3 2591461
# 4 1586960
# 2 426900
# 5 218595

# %%
loan_spec_log.to_csv("merge.csv", index = False)
