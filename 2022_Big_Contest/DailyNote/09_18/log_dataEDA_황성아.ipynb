# %% [markdown]
# # 1. 한도 조회, 신용 정보 조회, 대출 관리 서비스 이용, 여윳돈 계산기 서비스 이용, DSR 계산기 서비스 이용 중 어떤 것을 먼저 이용한 사람인가에 따른 차이점

# %%
# 패키지 설치
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# 데이터 불러오기
log_data = pd.read_csv('/content/gdrive/MyDrive/BigContest_data/log_data.csv')
log_data
# Out:
#           user_id               event            timestamp    mp_os  \
# 0          576409      StartLoanApply  2022-03-25 11:12:09  Android
# 1          576409  ViewLoanApplyIntro  2022-03-25 11:12:09  Android
# 2           72878        EndLoanApply  2022-03-25 11:14:44  Android
# 3          645317             OpenApp  2022-03-25 11:15:09      iOS
# 4          645317       UseLoanManage  2022-03-25 11:15:11      iOS
# ...           ...                 ...                  ...      ...
# 17843988   242442      StartLoanApply  2022-05-27 16:08:21  Android
# 17843989   242442        EndLoanApply  2022-05-27 16:08:21  Android
# 17843990   593062             OpenApp  2022-05-27 16:19:10  Android
# 17843991   593062               Login  2022-05-27 16:19:15  Android
# 17843992   593062       UseLoanManage  2022-05-27 16:19:19  Android
#
#          mp_app_version     date_cd
# 0                 3.8.2  2022-03-25
# 1                 3.8.2  2022-03-25
# 2                 3.8.4  2022-03-25
# 3                 3.6.1  2022-03-25
# 4                 3.6.1  2022-03-25
# ...                 ...         ...
# 17843988         3.13.0  2022-05-27
# 17843989         3.13.0  2022-05-27
# 17843990         3.13.0  2022-05-27
# 17843991         3.13.0  2022-05-27
# 17843992         3.13.0  2022-05-27
#
# [17843993 rows x 6 columns]

# %%
log_data.event.unique()
# Out:
# array(['StartLoanApply', 'ViewLoanApplyIntro', 'EndLoanApply', 'OpenApp',
#        'UseLoanManage', 'UsePrepayCalc', 'Login',
#        'CompleteIDCertification', 'UseDSRCalc', 'SignUp', 'GetCreditInfo'],
#       dtype=object)

# %%
log_data_1 = log_data[log_data['event'] == 'EndLoanApply']
log_data_2 = log_data_1.append(log_data[log_data['event'] == 'UseLoanManage'])
log_data_3 = log_data_2.append(log_data[log_data['event'] == 'UsePrepayCalc'])
log_data_4 = log_data_3.append(log_data[log_data['event'] == 'UseDSRCalc'])
log_data_new = log_data_4.append(log_data[log_data['event'] == 'GetCreditInfo'])

# %%
log_data_new
# Out:
#           user_id          event            timestamp    mp_os mp_app_version  \
# 2           72878   EndLoanApply  2022-03-25 11:14:44  Android          3.8.4
# 24         640185   EndLoanApply  2022-03-25 11:49:25      iOS          3.6.1
# 36         500083   EndLoanApply  2022-03-25 11:55:19      iOS          3.6.1
# 37         500083   EndLoanApply  2022-03-25 11:55:19      iOS          3.6.1
# 38         500083   EndLoanApply  2022-03-25 11:55:19      iOS          3.6.1
# ...           ...            ...                  ...      ...            ...
# 16823116   670303  GetCreditInfo  2022-06-20 21:35:41  android            466
# 16823117   879311  GetCreditInfo  2022-06-20 21:35:46  android            435
# 16823118    71130  GetCreditInfo  2022-06-20 21:35:46      iOS         3.13.0
# 16823119    51665  GetCreditInfo  2022-06-20 21:35:52  android            451
# 16823120   154759  GetCreditInfo  2022-06-20 21:35:55  android            416
#
#              date_cd
# 2         2022-03-25
# 24        2022-03-25
# 36        2022-03-25
# 37        2022-03-25
# 38        2022-03-25
# ...              ...
# 16823116  2022-06-20
# 16823117  2022-06-20
# 16823118  2022-06-20
# 16823119  2022-06-20
# 16823120  2022-06-20
#
# [6948181 rows x 6 columns]

# %%
group = log_data_new.groupby(['user_id', 'event'])['timestamp'].min()
group
# Out:
# user_id  event
# 1        GetCreditInfo    2022-05-03 14:52:28
#          UseLoanManage    2022-06-16 23:58:41
# 7        GetCreditInfo    2022-05-22 16:39:49
# 9        GetCreditInfo    2022-05-21 23:37:58
# 11       EndLoanApply     2022-03-24 10:59:46
#                                  ...
# 879694   EndLoanApply     2022-03-31 20:18:18
# 879695   EndLoanApply     2022-05-27 12:51:23
# 879696   EndLoanApply     2022-03-14 05:42:14
#          GetCreditInfo    2022-03-14 05:35:43
#          UseLoanManage    2022-03-14 05:35:41
# Name: timestamp, Length: 1070648, dtype: object

# %%
df_group = pd.DataFrame(group)
df_group
# Out:
#                                  timestamp
# user_id event
# 1       GetCreditInfo  2022-05-03 14:52:28
#         UseLoanManage  2022-06-16 23:58:41
# 7       GetCreditInfo  2022-05-22 16:39:49
# 9       GetCreditInfo  2022-05-21 23:37:58
# 11      EndLoanApply   2022-03-24 10:59:46
# ...                                    ...
# 879694  EndLoanApply   2022-03-31 20:18:18
# 879695  EndLoanApply   2022-05-27 12:51:23
# 879696  EndLoanApply   2022-03-14 05:42:14
#         GetCreditInfo  2022-03-14 05:35:43
#         UseLoanManage  2022-03-14 05:35:41
#
# [1070648 rows x 1 columns]

# %%
df_group_new = df_group.reset_index()
df_group_new
# Out:
#          user_id          event            timestamp
# 0              1  GetCreditInfo  2022-05-03 14:52:28
# 1              1  UseLoanManage  2022-06-16 23:58:41
# 2              7  GetCreditInfo  2022-05-22 16:39:49
# 3              9  GetCreditInfo  2022-05-21 23:37:58
# 4             11   EndLoanApply  2022-03-24 10:59:46
# ...          ...            ...                  ...
# 1070643   879694   EndLoanApply  2022-03-31 20:18:18
# 1070644   879695   EndLoanApply  2022-05-27 12:51:23
# 1070645   879696   EndLoanApply  2022-03-14 05:42:14
# 1070646   879696  GetCreditInfo  2022-03-14 05:35:43
# 1070647   879696  UseLoanManage  2022-03-14 05:35:41
#
# [1070648 rows x 3 columns]

# %%
df_final = df_group_new.drop_duplicates(['user_id'], keep = 'first')
df_final
# Out:
#          user_id          event            timestamp
# 0              1  GetCreditInfo  2022-05-03 14:52:28
# 2              7  GetCreditInfo  2022-05-22 16:39:49
# 3              9  GetCreditInfo  2022-05-21 23:37:58
# 4             11   EndLoanApply  2022-03-24 10:59:46
# 8             12   EndLoanApply  2022-03-14 01:16:26
# ...          ...            ...                  ...
# 1070637   879692   EndLoanApply  2022-04-18 17:05:32
# 1070640   879693   EndLoanApply  2022-05-13 11:34:29
# 1070643   879694   EndLoanApply  2022-03-31 20:18:18
# 1070644   879695   EndLoanApply  2022-05-27 12:51:23
# 1070645   879696   EndLoanApply  2022-03-14 05:42:14
#
# [510704 rows x 3 columns]

# %%
df_final.groupby(['event']).count()
# Out:
#                user_id  timestamp
# event
# EndLoanApply    302466     302466
# GetCreditInfo   207867     207867
# UseDSRCalc           3          3
# UseLoanManage      368        368

# %% [markdown]
# * 활용 방법: 각 user_id당 가장 먼저 접속한 event를 spec 데이터에 연결. 값이 없는 경우는 others라고 부여

# %% [markdown]
# # 2. 각 유저 ID 당 몇 번 접속 했는지 (날짜 개수)

# %%
grouped = log_data.groupby(['user_id', 'date_cd'])['user_id'].count()
grouped
# Out:
# user_id  date_cd
# 1        2022-05-03     2
#          2022-06-16     3
# 7        2022-05-22     1
# 9        2022-05-21     3
# 11       2022-03-24    12
#                        ..
# 879693   2022-06-29     1
# 879694   2022-03-31     6
# 879695   2022-05-27     4
# 879696   2022-03-14    11
# 879698   2022-05-24     3
# Name: user_id, Length: 2728153, dtype: int64

# %%
df_grouped = pd.DataFrame(grouped)
df_grouped
# Out:
#                     user_id
# user_id date_cd
# 1       2022-05-03        2
#         2022-06-16        3
# 7       2022-05-22        1
# 9       2022-05-21        3
# 11      2022-03-24       12
# ...                     ...
# 879693  2022-06-29        1
# 879694  2022-03-31        6
# 879695  2022-05-27        4
# 879696  2022-03-14       11
# 879698  2022-05-24        3
#
# [2728153 rows x 1 columns]

# %%
df_grouped.rename(columns = {'user_id' : 'user_id_cnt'}, inplace = True)
df_grouped
# Out:
#                     user_id_cnt
# user_id date_cd
# 1       2022-05-03            2
#         2022-06-16            3
# 7       2022-05-22            1
# 9       2022-05-21            3
# 11      2022-03-24           12
# ...                         ...
# 879693  2022-06-29            1
# 879694  2022-03-31            6
# 879695  2022-05-27            4
# 879696  2022-03-14           11
# 879698  2022-05-24            3
#
# [2728153 rows x 1 columns]

# %%
df_grouped_new = df_grouped.reset_index('date_cd')
df_grouped_new
# Out:
#             date_cd  user_id_cnt
# user_id
# 1        2022-05-03            2
# 1        2022-06-16            3
# 7        2022-05-22            1
# 9        2022-05-21            3
# 11       2022-03-24           12
# ...             ...          ...
# 879693   2022-06-29            1
# 879694   2022-03-31            6
# 879695   2022-05-27            4
# 879696   2022-03-14           11
# 879698   2022-05-24            3
#
# [2728153 rows x 2 columns]

# %%
df_grouped_new_1 = df_grouped_new.reset_index('user_id')
df_grouped_new_1
# Out:
#          user_id     date_cd  user_id_cnt
# 0              1  2022-05-03            2
# 1              1  2022-06-16            3
# 2              7  2022-05-22            1
# 3              9  2022-05-21            3
# 4             11  2022-03-24           12
# ...          ...         ...          ...
# 2728148   879693  2022-06-29            1
# 2728149   879694  2022-03-31            6
# 2728150   879695  2022-05-27            4
# 2728151   879696  2022-03-14           11
# 2728152   879698  2022-05-24            3
#
# [2728153 rows x 3 columns]
